# %% [markdown]
# <a href="https://colab.research.google.com/github/neuromatch/NeuroAI_Course/blob/main/projects/project-notebooks/Macrocircuits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> &nbsp; <a href="https://kaggle.com/kernels/welcome?src=https://raw.githubusercontent.com/neuromatch/NeuroAI_Course/main/projects/project-notebooks/Macrocircuits.ipynb" target="_parent"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open in Kaggle"/></a>

# %% [markdown]
# # Macrocircuits
#
# ***Macrocircuits: Leveraging neural architectural priors and modularity in embodied agents***
#
# **By Neuromatch Academy**
#
# **Content creators:** Divyansha Lachi, Kseniia Shilova
#
# **Content reviewers:** Eva Dyer, Hannah Choi
#
# __Production editors:__ Konstantine Tsafatinos, Ella Batty, Spiros Chavlis, Samuele Bolotta, Hlib Solodzhuk
#
# ---

# %% [markdown]
# ## Background
# This project explores how we can build a biologically inspired artificial neural network (ANN) architecture, derived from the C. Elegans motor circuit, for the control of a simulated Swimmer agent. Traditional motor control ANNs often rely on generic, fully connected multilayer perceptrons (MLPs), which demand extensive training data, offer limited transferability, and possess complex internal dynamics that challenge interpretability. The project aims to understand how the biologically motivated ANN, which is shaped by evolution to be highly structured and sparse, could help to solve these problems and provide advantages in the domain of motor control. We will train MLPs using algorithms such as PPO, DDPG, and ES, and compare their performance in terms of rewards and sample efficiency with our bio-inspired ANN. The project also includes visualizing the C. Elegans connectome and building the network using this circuitry. We will conduct various ablation analyses by removing sign and weight-sharing constraints, and altering environmental parameters like the swimmer’s length or viscosity. These investigations aim to understand how architecture and modularity impact performance and learning across different environments. Finally, the project aims at building an agent that is robust to environmental variations, navigating towards specific targets, and enhancing our understanding of bio-inspired motor control.
#
#
# **Relevant references:**
#
# - [Neural circuit architectural priors for embodied control](https://arxiv.org/abs/2201.05242)
# - [Hierarchical motor control in mammals and machines](https://www.nature.com/articles/s41467-019-13239-6)
# - [Continuous control with deep reinforcement learning](https://arxiv.org/pdf/1509.02971.pdf)
#
# *This notebook uses code from the following GitHub repository:* [ncap](https://github.com/nikhilxb/ncap) by Nikhil X. Bhattasali and Anthony M. Zador and Tatiana A. Engel.
#
# **Infrastructure note:** This notebook contains GPU install guide as well as CPU ones for different OS.

# %%
# @title Install and import feedback gadget

# !pip install vibecheck datatops --quiet

from vibecheck import DatatopsContentReviewContainer
def content_review(notebook_section: str):
    return DatatopsContentReviewContainer(
        "",  # No text prompt
        notebook_section,
        {
            "url": "https://pmyvdlilci.execute-api.us-east-1.amazonaws.com/klab",
            "name": "neuromatch_neuroai",
            "user_key": "wb2cxze8",
        },
    ).render()

feedback_prefix = "Project_Macrocircuits"

# %%
# @title Project Background

from ipywidgets import widgets
from IPython.display import YouTubeVideo
from IPython.display import IFrame
from IPython.display import display


class PlayVideo(IFrame):
  def __init__(self, id, source, page=1, width=400, height=300, **kwargs):
    self.id = id
    if source == 'Bilibili':
      src = f'https://player.bilibili.com/player.html?bvid={id}&page={page}'
    elif source == 'Osf':
      src = f'https://mfr.ca-1.osf.io/render?url=https://osf.io/download/{id}/?direct%26mode=render'
    super(PlayVideo, self).__init__(src, width, height, **kwargs)


def display_videos(video_ids, W=400, H=300, fs=1):
  tab_contents = []
  for i, video_id in enumerate(video_ids):
    out = widgets.Output()
    with out:
      if video_ids[i][0] == 'Youtube':
        video = YouTubeVideo(id=video_ids[i][1], width=W,
                             height=H, fs=fs, rel=0)
        print(f'Video available at https://youtube.com/watch?v={video.id}')
      else:
        video = PlayVideo(id=video_ids[i][1], source=video_ids[i][0], width=W,
                          height=H, fs=fs, autoplay=False)
        if video_ids[i][0] == 'Bilibili':
          print(f'Video available at https://www.bilibili.com/video/{video.id}')
        elif video_ids[i][0] == 'Osf':
          print(f'Video available at https://osf.io/{video.id}')
      display(video)
    tab_contents.append(out)
  return tab_contents


video_ids = [('Youtube', 'CwOUn0Bt4JU'), ('Bilibili', 'BV1Zx4y1t7BU')]
tab_contents = display_videos(video_ids, W=854, H=480)
tabs = widgets.Tab()
tabs.children = tab_contents
for i in range(len(tab_contents)):
  tabs.set_title(i, video_ids[i][0])
display(tabs)
# Out:
# Tab(children=(Output(), Output()), _titles={'0': 'Youtube', '1': 'Bilibili'})

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_project_background")
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='🙂', layout=Layout(height='auto', padding='0.5…

# %%
# @title Project slides

from IPython.display import IFrame
print("If you want to download the slides: https://osf.io/download/cz93b/")
IFrame(src="https://mfr.ca-1.osf.io/render?url=https://osf.io/download/cz93b/?direct%26mode=render", width=854, height=480)
# Out:
# If you want to download the slides: https://osf.io/download/cz93b/
#         <iframe
#             width="854"
#             height="480"
#             src="https://mfr.ca-1.osf.io/render?url=https://osf.io/download/cz93b/?direct%26mode=render"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#@title Project Template
from IPython.display import Image, display
import os
from pathlib import Path

url = "https://github.com/neuromatch/NeuroAI_Course/blob/main/projects/project-notebooks/static/NCAPProjectTemplate.png?raw=true"

display(Image(url=url))
# Out:
# <img src="https://github.com/neuromatch/NeuroAI_Course/blob/main/projects/project-notebooks/static/NCAPProjectTemplate.png?raw=true"/>

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_project_template")
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='🙂', layout=Layout(height='auto', padding='0.5…

# %% [markdown]
# **Tutorial links**
#
# This particular project connects a couple of distinct ideas explored throughout the course. Firstly, the innate ability to learn a certain set of actions quickly is the main topic of [Tutorial 4](https://neuroai.neuromatch.io/tutorials/W2D4_Macrolearning/student/W2D4_Tutorial4.html) for **W2D4** on biological meta-learning. The focus comes with the observation that the brain is not of a generic architecture but is a highly structured and optimized hierarchy of modules, the importance of which is highlighted in [Tutorial 3](https://neuroai.neuromatch.io/tutorials/W2D1_Macrocircuits/student/W2D1_Tutorial3.html) for **W2D1**, forming inductive bias for efficient motor control. The default model for the agent used here is already known Actor-Critic; you had the opportunity to observe in already mentioned tutorials as well as in [Tutorial 3](https://neuroai.neuromatch.io/tutorials/W1D2_ComparingTasks/student/W1D2_Tutorial3.html) for **W1D2**.

# %% [markdown]
# ---
# ## Scetion 0: Initial setup

# %% [markdown]
# **IF USING COLAB (recommended):**
#
# Uncomment the cell below and run it.

# %%
#@title Installing Dependencies (Colab GPU case, uncomment if you want to use this one)

# import distutils.util
# import os
# import subprocess
# if subprocess.run('nvidia-smi').returncode:
#   raise RuntimeError(
#       'Cannot communicate with GPU. '
#       'Make sure you are using a GPU Colab runtime. '
#       'Go to the Runtime menu and select Choose runtime type.')

# # Add an ICD config so that glvnd can pick up the Nvidia EGL driver.
# # This is usually installed as part of an Nvidia driver package, but the Colab
# # kernel doesn't install its driver via APT, and as a result the ICD is missing.
# # (https://github.com/NVIDIA/libglvnd/blob/master/src/EGL/icd_enumeration.md)
# NVIDIA_ICD_CONFIG_PATH = '/usr/share/glvnd/egl_vendor.d/10_nvidia.json'
# if not os.path.exists(NVIDIA_ICD_CONFIG_PATH):
#   with open(NVIDIA_ICD_CONFIG_PATH, 'w') as f:
#     f.write("""{
#     "file_format_version" : "1.0.0",
#     "ICD" : {
#         "library_path" : "libEGL_nvidia.so.0"
#     }
# }
# """)

# print('Installing dm_control...')
# !pip install -q dm_control>=1.0.16

# # Configure dm_control to use the EGL rendering backend (requires GPU)
# %env MUJOCO_GL=egl

# !echo Installed dm_control $(pip show dm_control | grep -Po "(?<=Version: ).+")
# !pip install -q dm-acme[envs]
# !mkdir output_videos

# %% [markdown]
# **IF USING KAGGLE (recommended):**
#
# Uncomment the cell below and run it.

# %%
#@title Installing Dependencies (Kaggle GPU case, uncomment if you want to use this one)

import subprocess

subprocess.run(["sudo", "apt-get", "install", "-y", "libgl1-mesa-glx", "libosmesa6"])
subprocess.run(["pip", "install", "-q", "imageio[ffmpeg]"])

print('Installing dm_control...')
# !pip install -q dm_control>=1.0.16

# %env MUJOCO_GL=osmesa

# !echo Installed dm_control $(pip show dm_control | grep -Po "(?<=Version: ).+")
# !pip install -q dm-acme[envs]
# !mkdir output_videos
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libgl1-mesa-glx is already the newest version (21.2.6-0ubuntu0.1~20.04.2).
# libosmesa6 is already the newest version (21.2.6-0ubuntu0.1~20.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 80 not upgraded.
# Installing dm_control...
# env: MUJOCO_GL=osmesa
# Installed dm_control 1.0.20
# mkdir: cannot create directory 'output_videos': File exists

# %% [markdown]
#  **IF RUNNING LOCALLY**
#
# Uncomment the relevant lines of code depending on your OS.

# %%
#@title Installing Dependencies (CPU case, comment if you want to use GPU one)

import subprocess
import os

############### For Linux #####################
# subprocess.run(["sudo", "apt-get", "install", "-y", "libglew-dev"])
# subprocess.run(["sudo", "apt-get", "install", "-y", "libglfw3"])
# subprocess.run(["sudo", "apt", "install", "ffmpeg"])
###############################################

############### For MacOS #####################
# subprocess.run(["brew", "install", "glew"])
# subprocess.run(["brew", "install", "glfw"])
###############################################

subprocess.run(["pip", "install", "-q", "ffmpeg"])
subprocess.run(["pip", "install", "-q", "dm-acme[envs]"])
subprocess.run(["pip", "install", "-q", "dm_control>=1.0.16"])

# !mkdir output_videos
# Out:
# mkdir: cannot create directory 'output_videos': File exists

# %% [markdown]
# **Imports and Utility Functions**

# %%
#@title Importing Libraries
import numpy as np
import collections
import argparse
import os
import yaml
import typing as T
import imageio
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
import seaborn as sns
from IPython.display import HTML

import dm_control as dm
import dm_control.suite.swimmer as swimmer
from dm_control.rl import control
from dm_control.utils import rewards
from dm_control import suite
from dm_control.suite.wrappers import pixels

from acme import wrappers

from torch import nn

# %%
#@title Utility code for displaying videos
def write_video(
  filepath: os.PathLike,
  frames: T.Iterable[np.ndarray],
  fps: int = 60,
  macro_block_size: T.Optional[int] = None,
  quality: int = 10,
  verbose: bool = False,
  **kwargs,
):
  """
  Saves a sequence of frames as a video file.

  Parameters:
  - filepath (os.PathLike): Path to save the video file.
  - frames (Iterable[np.ndarray]): An iterable of frames, where each frame is a numpy array.
  - fps (int, optional): Frames per second, defaults to 60.
  - macro_block_size (Optional[int], optional): Macro block size for video encoding, can affect compression efficiency.
  - quality (int, optional): Quality of the output video, higher values indicate better quality.
  - verbose (bool, optional): If True, prints the file path where the video is saved.
  - **kwargs: Additional keyword arguments passed to the imageio.get_writer function.

  Returns:
  None. The video is written to the specified filepath.
  """

  with imageio.get_writer(filepath,
                        fps=fps,
                        macro_block_size=macro_block_size,
                        quality=quality,
                        **kwargs) as video:
    if verbose: print('Saving video to:', filepath)
    for frame in frames:
      video.append_data(frame)


def display_video(
  frames: T.Iterable[np.ndarray],
  filename='output_videos/temp.mp4',
  fps=60,
  **kwargs,
):
  """
  Displays a video within a Jupyter Notebook from an iterable of frames.

  Parameters:
  - frames (Iterable[np.ndarray]): An iterable of frames, where each frame is a numpy array.
  - filename (str, optional): Temporary filename to save the video before display, defaults to 'output_videos/temp.mp4'.
  - fps (int, optional): Frames per second for the video display, defaults to 60.
  - **kwargs: Additional keyword arguments passed to the write_video function.

  Returns:
  HTML object: An HTML video element that can be displayed in a Jupyter Notebook.
  """

  # Write video to a temporary file.
  filepath = os.path.abspath(filename)
  write_video(filepath, frames, fps=fps, verbose=False, **kwargs)

  height, width, _ = frames[0].shape
  dpi = 70
  orig_backend = matplotlib.get_backend()
  matplotlib.use('Agg')  # Switch to headless 'Agg' to inhibit figure rendering.
  fig, ax = plt.subplots(1, 1, figsize=(width / dpi, height / dpi), dpi=dpi)
  matplotlib.use(orig_backend)  # Switch back to the original backend.
  ax.set_axis_off()
  ax.set_aspect('equal')
  ax.set_position([0, 0, 1, 1])
  im = ax.imshow(frames[0])
  def update(frame):
    im.set_data(frame)
    return [im]
  interval = 1000/fps
  anim = animation.FuncAnimation(fig=fig, func=update, frames=frames,
                                  interval=interval, blit=True, repeat=False)
  return HTML(anim.to_html5_video())

# %% [markdown]
# In this notebook we will explore the major components essential for this project.
#
#
# *   **Understanding the DeepMind Control Suite Swimmer Agent:** We will begin by exploring the swimmer agent provided by the DeepMind Control Suite. This section includes a detailed exploration of the agent's API, task customization capabilities, and how to adapt the environment to fit our experimental needs.
# *   **Training Models Using Various Reinforcement Learning Algorithms:** Next, we move on to learn how can we train models for the agents we created. We will be using Tonic_RL library to train our model. We will first train a standard MLP model using the Proximal Policy Optimization (PPO) algorithm.
#
# * **Training the NCAP model:** Finally we will define the NCAP model from [Neural Circuit Architectural Priors for Embodied Control](https://arxiv.org/abs/2201.05242) paper. We will train it using PPO and compare it against the MLP model we trained before.

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_initial_setup")
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='🙂', layout=Layout(height='auto', padding='0.5…

# %% [markdown]
# ---
# ## Section 1: Exploring the DeepMind Swimmer

# %% [markdown]
# ### 1.1 Create a basic swim task for the swimmer environment

# %% [markdown]
# First, we'll initialize a basic swimmer agent consisting of 6 links. Each agent requires a defined task and its corresponding reward function. In this instance, we've designed a swim forward task that involves the agent swimming forward in any direction.
#
# The environment is flexible, allowing for modifications to introduce additional tasks such as "swim only in the x-direction" or "move towards a ball."

# %%
_SWIM_SPEED = 0.1

@swimmer.SUITE.add()
def swim(
  n_links=6,
  viscosity=0, # z: enables playing with viscosity 
  desired_speed=_SWIM_SPEED,
  time_limit=swimmer._DEFAULT_TIME_LIMIT,
  random=None,
  environment_kwargs={},
):
  """Returns the Swim task for a n-link swimmer."""
  model_string, assets = swimmer.get_model_and_assets(n_links)
  physics = swimmer.Physics.from_xml_string(model_string, assets=assets)
  physics.model.opt.viscosity = viscosity # z: enables playing with viscosity 
  task = Swim(desired_speed=desired_speed, random=random)
  return control.Environment(
    physics,
    task,
    time_limit=time_limit,
    control_timestep=swimmer._CONTROL_TIMESTEP,
    **environment_kwargs,
  )


class Swim(swimmer.Swimmer):
  """Task to swim forwards at the desired speed."""
  def __init__(self, desired_speed=_SWIM_SPEED, **kwargs):
    super().__init__(**kwargs)
    self._desired_speed = desired_speed

  def initialize_episode(self, physics):
    super().initialize_episode(physics)
    # Hide target by setting alpha to 0.
    physics.named.model.mat_rgba['target', 'a'] = 0
    physics.named.model.mat_rgba['target_default', 'a'] = 0
    physics.named.model.mat_rgba['target_highlight', 'a'] = 0

  def get_observation(self, physics):
    """Returns an observation of joint angles and body velocities."""
    obs = collections.OrderedDict()
    obs['joints'] = physics.joints()
    obs['body_velocities'] = physics.body_velocities()
    return obs

  def get_reward(self, physics):
    """Returns a smooth reward that is 0 when stopped or moving backwards, and rises linearly to 1
    when moving forwards at the desired speed."""
    forward_velocity = -physics.named.data.sensordata['head_vel'][1]
    return rewards.tolerance(
      forward_velocity,
      bounds=(self._desired_speed, float('inf')),
      margin=self._desired_speed,
      value_at_margin=0.,
      sigmoid='linear',
    )

# %% [markdown]
# ### 1.2 Vizualizing an agent that takes random actions in the environment

# %% [markdown]
# Let's visualize the environment by executing a sequence of random actions on a swimmer agent. This involves applying random actions over a series of steps and compiling the rendered frames into a video to visualize the agent's behavior.

# %%
""" Renders the current environment state to an image """
def render(env):
    return env.physics.render(camera_id=0, width=640, height=480)

""" Tests a DeepMind control suite environment by executing a series of random actions """
def test_dm_control(env):
    env = wrappers.CanonicalSpecWrapper(env, clip=True)
    env = wrappers.SinglePrecisionWrapper(env)

    spec = env.action_spec()
    timestep = env.reset()
    frames = [render(env)]

    for _ in range(60):
        action = np.random.uniform(low=spec.minimum, high=spec.maximum, size=spec.shape)
        timestep = env.step(action)
        frames.append(render(env))
    return display_video(frames)

env = suite.load('swimmer', 'swim', task_kwargs={'random': 1})

# %%
test_dm_control(env)
# Out:
# <video width="640" height="480" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 1.3 Swimmer Agent API

# %% [markdown]
# The observation space consists of 25 total dimensions, combining joint positions and body velocities, while the action space involves 5 dimensions representing normalized joint forces.

# %% [markdown]
# **Observation Space**: 4k - 1 total (k = 6 $\rightarrow$ 23)
#
# - k - 1: joint positions $q_i \in [-\pi, \pi]$ (`joints`)
# - 3k: link linear velocities $vx_i, vy_i \in \mathbb{R}$ and rotational velocity $wz_i \in \mathbb{R}$ (`body_velocities`)

# %%
env.observation_spec()
# Out:
# OrderedDict([('joints',
#               Array(shape=(5,), dtype=dtype('float64'), name='joints')),
#              ('body_velocities',
#               Array(shape=(18,), dtype=dtype('float64'), name='body_velocities'))])

# %% [markdown]
# **Action Space**: k - 1 total (k = 6 $\rightarrow$ 5)
#
# - k - 1: joint normalized force $\ddot{q}_i \in [-1, 1]$

# %%
env.action_spec()
# Out:
# BoundedArray(shape=(5,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1.])

# %% [markdown]
# ### 1.4 Example of simple modification to the agent

# %% [markdown]
# Let's make a new swimmer agent with 12 links instead of 6, introducing complexity. Additionally, we have the flexibility to adjust various other parameters.

# %%
@swimmer.SUITE.add()
def swim_12_links(
  n_links=12,
  desired_speed=_SWIM_SPEED,
  time_limit=swimmer._DEFAULT_TIME_LIMIT,
  random=None,
  environment_kwargs={},
):
  """Returns the Swim task for a n-link swimmer."""
  model_string, assets = swimmer.get_model_and_assets(n_links)
  physics = swimmer.Physics.from_xml_string(model_string, assets=assets)
  task = Swim(desired_speed=desired_speed, random=random)
  return control.Environment(
    physics,
    task,
    time_limit=time_limit,
    control_timestep=swimmer._CONTROL_TIMESTEP,
    **environment_kwargs,
  )

env = suite.load('swimmer', 'swim_12_links', task_kwargs={'random': 1})
test_dm_control(env)
# Out:
# <video width="640" height="480" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# We can visualize this longer agent using our previously defined test_dm_control function.

# %% [markdown]
# ❓

# %% [markdown]
# Using the API provided by Deepmind we can create any kind of changes to the agent and the environment.
#
# Try to make the following changes to make yourself more familiar with the swimmer.
#
# *   ***Adding a target (like a ball) to this environment at some x distance away from the agent.***
# *   ***Increasing the viscosity of the environment.***
#
#
#
# Have a look at the following links to see what kind of assets you will need to modify to make these changes.
#
#
# *   [swimmer.py](https://github.com/google-deepmind/dm_control/blob/main/dm_control/suite/swimmer.py)
# *   [swimmer.xml](https://github.com/google-deepmind/dm_control/blob/main/dm_control/suite/swimmer.xml)

# %%
# add your code

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_exploring_deepmind_swimmer")
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='🙂', layout=Layout(height='auto', padding='0.5…

# %% [markdown]
# ---
# ## Section 2: Training models on the swim task

# %% [markdown]
# To train the agents we defined in the previous section, we will utilize standard reinforcement learning (RL) algorithms. For the purposes of this tutorial, we will employ the [tonic_rl](https://github.com/fabiopardo/tonic) library, which provides a robust framework for training RL agents. Throughout most of this project, you will primarily be modifying the environment or the model architecture. Therefore, I suggest treating these algorithms as a "black box" for now. Simply put, you input an untrained model, and the algorithm processes and returns a well-trained model. This approach allows us to focus on the impact of different architectures and environmental settings without delving deeply into the algorithmic complexities at this stage.

# %%
#@title Download and install tonic library for training agents

import contextlib
import io

with contextlib.redirect_stdout(io.StringIO()): #to suppress output
    # !git clone https://github.com/neuromatch/tonic
    # %cd tonic

# %% [markdown]
# ### Section 2.1 Defining the train function
#
# First we defined a general training function to train any agent on any given environment with a variety of available algorithms. Given below are some of the parameter definitions of the function. You'll likely want to adjust these parameters to customize the training process for an agent in a specific environment using your chosen algorithm from the tonic library:
#
# * **Header**: Python code required to run before training begins, primarily for importing essential libraries or modules.
#
# * **Agent**: The agent that will undergo training; refer to section 3.2 and 4.2 for definitions of MLP and NCAP respectively.
#
# * **Environment**: The training environment for the agent. Ensure it is registered with the DeepMind Control Suite as detailed in section 2.
#
# * **Name**: The experiment's name, which will be utilized for log and model saving purposes.
#
# * **Trainer**: The trainer instance selected for use. It allows the configuration of the training steps, model saving frequency, and other training-related parameters.

# %%
import tonic
import tonic.torch

def train(
  header,
  agent,
  environment,
  name = 'test',
  trainer = 'tonic.Trainer()',
  before_training = None,
  after_training = None,
  parallel = 1,
  sequential = 1,
  seed = 0
):
  """
  Some additional parameters:

  - before_training: Python code to execute immediately before the training loop commences, suitable for setup actions needed after initialization but prior to training.
  - after_training: Python code to run once the training loop concludes, ideal for teardown or analytical purposes.
  - parallel: The count of environments to execute in parallel. Limited to 1 in a Colab notebook, but if additional resources are available, this number can be increased to expedite training.
  - sequential: The number of sequential steps the environment runs before sending observations back to the agent. This setting is useful for temporal batching. It can be disregarded for this tutorial's purposes.
  - seed: The experiment's random seed, guaranteeing the reproducibility of the training process.

  """
  # Capture the arguments to save them, e.g. to play with the trained agent.
  args = dict(locals())

  # Run the header first, e.g. to load an ML framework.
  if header:
    exec(header)

  # Build the train and test environments.
  _environment = environment
  environment = tonic.environments.distribute(lambda: eval(_environment), parallel, sequential)
  test_environment = tonic.environments.distribute(lambda: eval(_environment))


  # Build the agent.
  agent = eval(agent)
  agent.initialize(
    observation_space=test_environment.observation_space,
    action_space=test_environment.action_space, seed=seed)

  # Choose a name for the experiment.
  if hasattr(test_environment, 'name'):
    environment_name = test_environment.name
  else:
    environment_name = test_environment.__class__.__name__
  if not name:
    if hasattr(agent, 'name'):
      name = agent.name
    else:
      name = agent.__class__.__name__
    if parallel != 1 or sequential != 1:
      name += f'-{parallel}x{sequential}'

  # Initialize the logger to save data to the path environment/name/seed.
  path = os.path.join('data', 'local', 'experiments', 'tonic', environment_name, name)
  tonic.logger.initialize(path, script_path=None, config=args)

  # Build the trainer.
  trainer = eval(trainer)
  trainer.initialize(
    agent=agent,
    environment=environment,
    test_environment=test_environment,
  )
  # Run some code before training.
  if before_training:
    exec(before_training)

  # Train.
  trainer.run()

  # Run some code after training.
  if after_training:
    exec(after_training)

# %% [markdown]
# ### Section 2.2 Training MLP model on swim task

# %% [markdown]
# Now we are going to define a function for creating an actor-critic model suitable for Proximal Policy Optimization (PPO) using a Multi-Layer Perceptron (MLP) architecture.

# %%
from tonic.torch import models, normalizers
import torch

def ppo_mlp_model(
  actor_sizes=(64, 64),
  actor_activation=torch.nn.Tanh,
  critic_sizes=(64, 64),
  critic_activation=torch.nn.Tanh,
):

  """
  Constructs an ActorCritic model with specified architectures for the actor and critic networks.

  Parameters:
  - actor_sizes (tuple): Sizes of the layers in the actor MLP.
  - actor_activation (torch activation): Activation function used in the actor MLP.
  - critic_sizes (tuple): Sizes of the layers in the critic MLP.
  - critic_activation (torch activation): Activation function used in the critic MLP.

  Returns:
  - models.ActorCritic: An ActorCritic model comprising an actor and a critic with MLP torsos,
    equipped with a Gaussian policy head for the actor and a value head for the critic,
    along with observation normalization.
  """

  return models.ActorCritic(
    actor=models.Actor(
      encoder=models.ObservationEncoder(),
      torso=models.MLP(actor_sizes, actor_activation),
      head=models.DetachedScaleGaussianPolicyHead(),
    ),
    critic=models.Critic(
      encoder=models.ObservationEncoder(),
      torso=models.MLP(critic_sizes, critic_activation),
      head=models.ValueHead(),
    ),
    observation_normalizer=normalizers.MeanStd(),
  )

# %% [markdown]
# Next we call the train function which initiates the training process for the provided agent using the Tonic library. It specifies the components necessary for training, including the model, environment, and training parameters:
#
# **Agent**: A Proximal Policy Optimization (PPO) agent with a custom Multi-Layer Perceptron (MLP) model architecture, configured with 256 units in each of two layers for both the actor and the critic.
#
# **Environment**: The training environment is set to "swimmer-swim" from the Control Suite, a benchmark suite for continuous control tasks.
#
# **Name**: The experiment is named 'mlp_256', which is useful for identifying logs and saved models associated with this training run.
#
# **Trainer**: Specifies the training configuration, including the total number of steps (5e5) and the frequency of saving the model (1e5 steps).

# %% [markdown]
# *Note:* The model will checkpoint every 'save_steps' amount of training steps*

# %% [markdown]
# ⏳
#
# The model can take some time to train so feel free to skip the training for now. We have provided the pretrained model for you to play with. Move on to the next section to vizualize a agent with the pretrained model.
#
# Uncomment the cell below if you want to perform the training.

# %%
train('import tonic.torch',
      'tonic.torch.agents.PPO(model=ppo_mlp_model(actor_sizes=(256, 256), critic_sizes=(256,256)))',
      'tonic.environments.ControlSuite("swimmer-swim")',
      name = 'mlp_256',
      trainer = 'tonic.Trainer(steps=int(5e5),save_steps=int(1e5))')

# %% [markdown]
# ❓

# %% [markdown]
# **Try playing with the parameters of the trainer and the MLP model and see how it affects the performance.**
#
#
# *   ***How do the actor and the critic model size affect the performance.***
# *   ***Consider increasing the number of steps in trainer to train the model for longer.***
# *   ***Explore [Tonic library](https://github.com/fabiopardo/tonic) to see what algorithms we can use to train our agents. (D4PG is usually faster than PPO)***

# %%
# z: train with viscosity=0.00002
train('import tonic.torch',
      'tonic.torch.agents.PPO(model=ppo_mlp_model(actor_sizes=(256, 256), critic_sizes=(256,256)))',
      'tonic.environments.ControlSuite("swimmer-swim",task_kwargs = {"viscosity": 0.00002})',
      name = 'mlp_256_viscosity_0.00002',
      trainer = 'tonic.Trainer(steps=int(5e5),save_steps=int(1e5))')
# Out:
# /opt/conda/lib/python3.10/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Config file saved to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.00002/config.yaml
#           Time left:  epoch 0:00:00  total 0:11:43
# actor
#   clip fraction                                        0.149
#   entropy                                               1.05
#   iterations                                            23.5
#   kl                                                 0.00878
#   loss                                               -0.0172
#   std                                                  0.692
#   stop                                                0.0319
# critic
#   iterations                                              80
#   loss                                                  2.62
#   v                                                     5.77
# test
#   action
#     max                                                 3.05
#     mean                                             -0.0275
#     min                                                -2.68
#     size                                               5,000
#     std                                                 0.72
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  229
#     mean                                                 210
#     min                                                  193
#     size                                                   5
#     std                                                 12.8
# train
#   action
#     max                                                 2.87
#     mean                                              -0.032
#     min                                                -3.12
#     size                                              20,000
#     std                                                0.702
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  209
#     mean                                                 138
#     min                                                 79.6
#     size                                                  20
#     std                                                 43.5
#   episodes                                                20
#   epoch seconds                                           34
#   epoch steps                                          2e+04
#   epochs                                                   1
#   seconds                                                 34
#   steps                                                2e+04
#   steps per second                                       588
#   worker steps                                         2e+04
#
# Logging data to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.00002/log.csv
#           Time left:  epoch 0:00:00  total 0:12:06
# actor
#   clip fraction                                       0.0926
#   entropy                                               1.05
#   iterations                                             3.4
#   kl                                                 0.00804
#   loss                                               -0.0069
#   std                                                   0.69
#   stop                                                 0.294
# critic
#   iterations                                              80
#   loss                                                   2.3
#   v                                                     19.6
# test
#   action
#     max                                                 3.32
#     mean                                             0.00796
#     min                                                -3.38
#     size                                               5,000
#     std                                                 0.84
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  425
#     mean                                                 417
#     min                                                  407
#     size                                                   5
#     std                                                 8.23
# train
#   action
#     max                                                 3.86
#     mean                                            -0.00961
#     min                                                -3.54
#     size                                              20,000
#     std                                                0.781
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  417
#     mean                                                 327
#     min                                                  226
#     size                                                  20
#     std                                                 63.5
#   episodes                                                40
#   epoch seconds                                         33.9
#   epoch steps                                          2e+04
#   epochs                                                   2
#   seconds                                                 68
#   steps                                                4e+04
#   steps per second                                       591
#   worker steps                                         4e+04
#
#           Time left:  epoch 0:00:00  total 0:11:53
# actor
#   clip fraction                                       0.0998
#   entropy                                               1.04
#   iterations                                             3.8
#   kl                                                 0.00866
#   loss                                               -0.0048
#   std                                                  0.687
#   stop                                                 0.263
# critic
#   iterations                                              80
#   loss                                                  1.69
#   v                                                     36.8
# test
#   action
#     max                                                 3.51
#     mean                                             0.00628
#     min                                                -3.68
#     size                                               5,000
#     std                                                0.905
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  514
#     mean                                                 504
#     min                                                  498
#     size                                                   5
#     std                                                 5.66
# train
#   action
#     max                                                 3.15
#     mean                                            -0.00103
#     min                                                -3.39
#     size                                              20,000
#     std                                                0.878
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  506
#     mean                                                 464
#     min                                                  424
#     size                                                  20
#     std                                                 23.8
#   episodes                                                60
#   epoch seconds                                           34
#   epoch steps                                          2e+04
#   epochs                                                   3
#   seconds                                                102
#   steps                                                6e+04
#   steps per second                                       589
#   worker steps                                         6e+04
#
#           Time left:  epoch 0:00:00  total 0:11:49
# actor
#   clip fraction                                        0.136
#   entropy                                               1.02
#   iterations                                            51.2
#   kl                                                 0.00894
#   loss                                               -0.0176
#   std                                                  0.673
#   stop                                               0.00781
# critic
#   iterations                                              80
#   loss                                                 0.888
#   v                                                     47.6
# test
#   action
#     max                                                 3.52
#     mean                                             -0.0127
#     min                                                -3.42
#     size                                               5,000
#     std                                                0.942
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  576
#     mean                                                 564
#     min                                                  555
#     size                                                   5
#     std                                                 7.51
# train
#   action
#     max                                                  3.6
#     mean                                             -0.0171
#     min                                                -3.35
#     size                                              20,000
#     std                                                0.922
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  571
#     mean                                                 531
#     min                                                  487
#     size                                                  20
#     std                                                 21.1
#   episodes                                                80
#   epoch seconds                                         37.9
#   epoch steps                                          2e+04
#   epochs                                                   4
#   seconds                                                140
#   steps                                                8e+04
#   steps per second                                       528
#   worker steps                                         8e+04
#
#           Time left:  epoch 0:00:00  total 0:11:30
# actor
#   clip fraction                                        0.121
#   entropy                                              0.985
#   iterations                                            34.2
#   kl                                                 0.00871
#   loss                                               -0.0172
#   std                                                  0.648
#   stop                                                0.0175
# critic
#   iterations                                              80
#   loss                                                 0.487
#   v                                                     55.1
# test
#   action
#     max                                                 3.19
#     mean                                             -0.0131
#     min                                                -3.25
#     size                                               5,000
#     std                                                0.945
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  619
#     mean                                                 612
#     min                                                  607
#     size                                                   5
#     std                                                 5.47
# train
#   action
#     max                                                 3.37
#     mean                                             -0.0174
#     min                                                -3.27
#     size                                              20,000
#     std                                                0.944
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  612
#     mean                                                 586
#     min                                                  569
#     size                                                  20
#     std                                                 12.3
#   episodes                                               100
#   epoch seconds                                         37.4
#   epoch steps                                          2e+04
#   epochs                                                   5
#   seconds                                                177
#   steps                                                1e+05
#   steps per second                                       535
#   worker steps                                         1e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.00002/checkpoints/step_100000.pt
#           Time left:  epoch 0:00:00  total 0:11:03
# actor
#   clip fraction                                        0.141
#   entropy                                              0.951
#   iterations                                              34
#   kl                                                  0.0089
#   loss                                               -0.0187
#   std                                                  0.627
#   stop                                                0.0176
# critic
#   iterations                                              80
#   loss                                                 0.412
#   v                                                     60.7
# test
#   action
#     max                                                 3.25
#     mean                                              -0.015
#     min                                                -3.08
#     size                                               5,000
#     std                                                0.968
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  664
#     mean                                                 653
#     min                                                  642
#     size                                                   5
#     std                                                 7.66
# train
#   action
#     max                                                 3.62
#     mean                                             -0.0167
#     min                                                -3.53
#     size                                              20,000
#     std                                                0.957
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  656
#     mean                                                 632
#     min                                                  614
#     size                                                  20
#     std                                                 11.4
#   episodes                                               120
#   epoch seconds                                         36.8
#   epoch steps                                          2e+04
#   epochs                                                   6
#   seconds                                                214
#   steps                                              1.2e+05
#   steps per second                                       544
#   worker steps                                       1.2e+05
#
#           Time left:  epoch 0:00:00  total 0:10:37
# actor
#   clip fraction                                        0.128
#   entropy                                              0.909
#   iterations                                            49.2
#   kl                                                 0.00948
#   loss                                               -0.0188
#   std                                                  0.601
#   stop                                               0.00813
# critic
#   iterations                                              80
#   loss                                                  0.37
#   v                                                     65.2
# test
#   action
#     max                                                 3.23
#     mean                                            -0.00713
#     min                                                -3.21
#     size                                               5,000
#     std                                                0.969
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  704
#     mean                                                 694
#     min                                                  684
#     size                                                   5
#     std                                                 6.89
# train
#   action
#     max                                                 3.65
#     mean                                            -0.00399
#     min                                                 -3.5
#     size                                              20,000
#     std                                                0.965
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  691
#     mean                                                 668
#     min                                                  642
#     size                                                  20
#     std                                                 12.1
#   episodes                                               140
#   epoch seconds                                         38.3
#   epoch steps                                          2e+04
#   epochs                                                   7
#   seconds                                                253
#   steps                                              1.4e+05
#   steps per second                                       522
#   worker steps                                       1.4e+05
#
#           Time left:  epoch 0:00:00  total 0:10:00
# actor
#   clip fraction                                        0.111
#   entropy                                              0.873
#   iterations                                             9.8
#   kl                                                  0.0096
#   loss                                               -0.0101
#   std                                                   0.58
#   stop                                                 0.102
# critic
#   iterations                                              80
#   loss                                                 0.337
#   v                                                     69.6
# test
#   action
#     max                                                 3.14
#     mean                                             -0.0116
#     min                                                -3.36
#     size                                               5,000
#     std                                                 0.98
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  742
#     mean                                                 734
#     min                                                  725
#     size                                                   5
#     std                                                 6.17
# train
#   action
#     max                                                 3.46
#     mean                                             0.00138
#     min                                                -3.44
#     size                                              20,000
#     std                                                0.973
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  737
#     mean                                                 711
#     min                                                  692
#     size                                                  20
#     std                                                 13.4
#   episodes                                               160
#   epoch seconds                                         34.7
#   epoch steps                                          2e+04
#   epochs                                                   8
#   seconds                                                287
#   steps                                              1.6e+05
#   steps per second                                       577
#   worker steps                                       1.6e+05
#
#           Time left:  epoch 0:00:00  total 0:09:22
# actor
#   clip fraction                                        0.124
#   entropy                                              0.855
#   iterations                                            25.2
#   kl                                                 0.00843
#   loss                                               -0.0164
#   std                                                  0.569
#   stop                                                0.0297
# critic
#   iterations                                              80
#   loss                                                 0.393
#   v                                                     73.5
# test
#   action
#     max                                                 2.88
#     mean                                            -0.00504
#     min                                                -3.22
#     size                                               5,000
#     std                                                0.978
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  775
#     mean                                                 770
#     min                                                  767
#     size                                                   5
#     std                                                 2.94
# train
#   action
#     max                                                 3.52
#     mean                                            -0.00394
#     min                                                -3.26
#     size                                              20,000
#     std                                                0.982
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  769
#     mean                                                 750
#     min                                                  730
#     size                                                  20
#     std                                                 11.1
#   episodes                                               180
#   epoch seconds                                         33.7
#   epoch steps                                          2e+04
#   epochs                                                   9
#   seconds                                                321
#   steps                                              1.8e+05
#   steps per second                                       594
#   worker steps                                       1.8e+05
#
#           Time left:  epoch 0:00:00  total 0:08:50
# actor
#   clip fraction                                        0.134
#   entropy                                              0.831
#   iterations                                            37.6
#   kl                                                  0.0105
#   loss                                               -0.0189
#   std                                                  0.556
#   stop                                                 0.016
# critic
#   iterations                                              80
#   loss                                                 0.478
#   v                                                     77.7
# test
#   action
#     max                                                 2.94
#     mean                                             -0.0179
#     min                                                -3.22
#     size                                               5,000
#     std                                                0.983
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  830
#     mean                                                 824
#     min                                                  815
#     size                                                   5
#     std                                                 5.94
# train
#   action
#     max                                                 3.12
#     mean                                            -0.00414
#     min                                                 -3.4
#     size                                              20,000
#     std                                                0.981
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  820
#     mean                                                 797
#     min                                                  767
#     size                                                  20
#     std                                                 15.1
#   episodes                                               200
#   epoch seconds                                         36.8
#   epoch steps                                          2e+04
#   epochs                                                  10
#   seconds                                                358
#   steps                                                2e+05
#   steps per second                                       544
#   worker steps                                         2e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.00002/checkpoints/step_200000.pt
#           Time left:  epoch 0:00:00  total 0:08:16
# actor
#   clip fraction                                        0.113
#   entropy                                                0.8
#   iterations                                            36.8
#   kl                                                  0.0103
#   loss                                               -0.0172
#   std                                                  0.539
#   stop                                                0.0163
# critic
#   iterations                                              80
#   loss                                                 0.492
#   v                                                     82.1
# test
#   action
#     max                                                 2.84
#     mean                                           -0.000454
#     min                                                -3.12
#     size                                               5,000
#     std                                                0.973
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  859
#     mean                                                 849
#     min                                                  839
#     size                                                   5
#     std                                                  6.6
# train
#   action
#     max                                                 3.14
#     mean                                            -0.00916
#     min                                                -3.37
#     size                                              20,000
#     std                                                0.982
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  862
#     mean                                                 839
#     min                                                  820
#     size                                                  20
#     std                                                 10.4
#   episodes                                               220
#   epoch seconds                                         36.5
#   epoch steps                                          2e+04
#   epochs                                                  11
#   seconds                                                395
#   steps                                              2.2e+05
#   steps per second                                       549
#   worker steps                                       2.2e+05
#
#           Time left:  epoch 0:00:00  total 0:07:42
# actor
#   clip fraction                                        0.114
#   entropy                                              0.766
#   iterations                                            37.6
#   kl                                                  0.0098
#   loss                                               -0.0174
#   std                                                  0.521
#   stop                                                 0.016
# critic
#   iterations                                              80
#   loss                                                 0.388
#   v                                                     85.8
# test
#   action
#     max                                                 3.12
#     mean                                            -0.00258
#     min                                                   -3
#     size                                               5,000
#     std                                                0.979
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  877
#     mean                                                 872
#     min                                                  863
#     size                                                   5
#     std                                                 5.25
# train
#   action
#     max                                                  3.5
#     mean                                            -0.00864
#     min                                                -3.18
#     size                                              20,000
#     std                                                0.977
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  884
#     mean                                                 869
#     min                                                  854
#     size                                                  20
#     std                                                 9.59
#   episodes                                               240
#   epoch seconds                                         36.7
#   epoch steps                                          2e+04
#   epochs                                                  12
#   seconds                                                431
#   steps                                              2.4e+05
#   steps per second                                       545
#   worker steps                                       2.4e+05
#
#           Time left:  epoch 0:00:00  total 0:07:08
# actor
#   clip fraction                                        0.111
#   entropy                                               0.72
#   iterations                                              48
#   kl                                                  0.0115
#   loss                                               -0.0174
#   std                                                  0.498
#   stop                                                0.0125
# critic
#   iterations                                              80
#   loss                                                 0.264
#   v                                                     88.5
# test
#   action
#     max                                                 2.88
#     mean                                            -0.00358
#     min                                                 -2.9
#     size                                               5,000
#     std                                                0.973
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  910
#     mean                                                 903
#     min                                                  898
#     size                                                   5
#     std                                                 4.97
# train
#   action
#     max                                                 3.32
#     mean                                            -0.00537
#     min                                                -3.07
#     size                                              20,000
#     std                                                 0.98
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  907
#     mean                                                 887
#     min                                                  871
#     size                                                  20
#     std                                                 9.14
#   episodes                                               260
#   epoch seconds                                         36.7
#   epoch steps                                          2e+04
#   epochs                                                  13
#   seconds                                                468
#   steps                                              2.6e+05
#   steps per second                                       544
#   worker steps                                       2.6e+05
#
#           Time left:  epoch 0:00:00  total 0:06:33
# actor
#   clip fraction                                        0.119
#   entropy                                              0.672
#   iterations                                            47.6
#   kl                                                  0.0105
#   loss                                               -0.0183
#   std                                                  0.474
#   stop                                                0.0126
# ...
#     mean                                             -0.0104
#     min                                                -2.71
#     size                                              20,000
#     std                                                0.939
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  975
#     mean                                                 953
#     min                                                  924
#     size                                                  20
#     std                                                 11.4
#   episodes                                               420
#   epoch seconds                                         36.2
#   epoch steps                                          2e+04
#   epochs                                                  21
#   seconds                                                752
#   steps                                              4.2e+05
#   steps per second                                       552
#   worker steps                                       4.2e+05
#
#           Time left:  epoch 0:00:00  total 0:01:46
# actor
#   clip fraction                                       0.0947
#   entropy                                               0.44
#   iterations                                            17.4
#   kl                                                  0.0104
#   loss                                              -0.00898
#   std                                                  0.377
#   stop                                                0.0575
# critic
#   iterations                                              80
#   loss                                                 0.048
#   v                                                     97.5
# test
#   action
#     max                                                  2.6
#     mean                                            -0.00893
#     min                                                -2.47
#     size                                               5,000
#     std                                                0.939
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  968
#     mean                                                 961
#     min                                                  954
#     size                                                   5
#     std                                                 5.73
# train
#   action
#     max                                                 2.67
#     mean                                            -0.00773
#     min                                                -2.37
#     size                                              20,000
#     std                                                0.936
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  977
#     mean                                                 960
#     min                                                  937
#     size                                                  20
#     std                                                 8.92
#   episodes                                               440
#   epoch seconds                                         34.5
#   epoch steps                                          2e+04
#   epochs                                                  22
#   seconds                                                787
#   steps                                              4.4e+05
#   steps per second                                       580
#   worker steps                                       4.4e+05
#
#           Time left:  epoch 0:00:00  total 0:01:11
# actor
#   clip fraction                                        0.111
#   entropy                                              0.418
#   iterations                                            32.6
#   kl                                                 0.00981
#   loss                                               -0.0126
#   std                                                  0.369
#   stop                                                0.0245
# critic
#   iterations                                              80
#   loss                                                0.0494
#   v                                                     97.8
# test
#   action
#     max                                                 2.63
#     mean                                            -0.00521
#     min                                                -2.31
#     size                                               5,000
#     std                                                0.933
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  975
#     mean                                                 960
#     min                                                  952
#     size                                                   5
#     std                                                 8.12
# train
#   action
#     max                                                 2.58
#     mean                                            -0.00419
#     min                                                -2.69
#     size                                              20,000
#     std                                                0.938
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  977
#     mean                                                 958
#     min                                                  946
#     size                                                  20
#     std                                                 8.14
#   episodes                                               460
#   epoch seconds                                         35.9
#   epoch steps                                          2e+04
#   epochs                                                  23
#   seconds                                                823
#   steps                                              4.6e+05
#   steps per second                                       557
#   worker steps                                       4.6e+05
#
#           Time left:  epoch 0:00:00  total 0:00:35
# actor
#   clip fraction                                        0.101
#   entropy                                              0.401
#   iterations                                             6.8
#   kl                                                 0.00951
#   loss                                              -0.00484
#   std                                                  0.363
#   stop                                                 0.147
# critic
#   iterations                                              80
#   loss                                                0.0345
#   v                                                     97.9
# test
#   action
#     max                                                 2.66
#     mean                                            -0.00241
#     min                                                -2.46
#     size                                               5,000
#     std                                                0.938
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  975
#     mean                                                 967
#     min                                                  960
#     size                                                   5
#     std                                                 5.05
# train
#   action
#     max                                                 2.67
#     mean                                            -0.00445
#     min                                                -2.72
#     size                                              20,000
#     std                                                0.938
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  976
#     mean                                                 961
#     min                                                  947
#     size                                                  20
#     std                                                 9.05
#   episodes                                               480
#   epoch seconds                                         33.5
#   epoch steps                                          2e+04
#   epochs                                                  24
#   seconds                                                856
#   steps                                              4.8e+05
#   steps per second                                       597
#   worker steps                                       4.8e+05
#
#              Time left:  epoch 0:00:00  total
# actor
#   clip fraction                                        0.111
#   entropy                                               0.39
#   iterations                                            11.2
#   kl                                                  0.0104
#   loss                                              -0.00974
#   std                                                  0.359
#   stop                                                0.0893
# critic
#   iterations                                              80
#   loss                                                0.0303
#   v                                                       98
# test
#   action
#     max                                                  2.4
#     mean                                            -0.00876
#     min                                                -2.52
#     size                                               5,000
#     std                                                 0.94
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  980
#     mean                                                 968
#     min                                                  957
#     size                                                   5
#     std                                                 7.99
# train
#   action
#     max                                                 2.55
#     mean                                            -0.00907
#     min                                                -2.44
#     size                                              20,000
#     std                                                0.938
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  974
#     mean                                                 959
#     min                                                  940
#     size                                                  20
#     std                                                 9.09
#   episodes                                               500
#   epoch seconds                                         33.8
#   epoch steps                                          2e+04
#   epochs                                                  25
#   seconds                                                890
#   steps                                                5e+05
#   steps per second                                       592
#   worker steps                                         5e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.00002/checkpoints/step_500000.pt

# %%
# z: train with viscosity=0.0009
train('import tonic.torch',
      'tonic.torch.agents.PPO(model=ppo_mlp_model(actor_sizes=(256, 256), critic_sizes=(256,256)))',
      'tonic.environments.ControlSuite("swimmer-swim",task_kwargs = {"viscosity": 0.0009})',
      name = 'mlp_256_viscosity_0.0009',
      trainer = 'tonic.Trainer(steps=int(5e5),save_steps=int(1e5))')
# Out:
# /opt/conda/lib/python3.10/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Config file saved to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.0009/config.yaml
#           Time left:  epoch 0:00:00  total 0:12:11
# actor
#   clip fraction                                        0.135
#   entropy                                               1.05
#   iterations                                            23.5
#   kl                                                 0.00739
#   loss                                               -0.0163
#   std                                                  0.692
#   stop                                                0.0319
# critic
#   iterations                                              80
#   loss                                                  2.36
#   v                                                     4.75
# test
#   action
#     max                                                 2.85
#     mean                                             -0.0323
#     min                                                 -2.7
#     size                                               5,000
#     std                                                0.712
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  210
#     mean                                                 201
#     min                                                  191
#     size                                                   5
#     std                                                 6.98
# train
#   action
#     max                                                 2.91
#     mean                                             -0.0403
#     min                                                -3.15
#     size                                              20,000
#     std                                                  0.7
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  209
#     mean                                                 127
#     min                                                 73.5
#     size                                                  20
#     std                                                 41.8
#   episodes                                                20
#   epoch seconds                                         35.3
#   epoch steps                                          2e+04
#   epochs                                                   1
#   seconds                                               35.3
#   steps                                                2e+04
#   steps per second                                       567
#   worker steps                                         2e+04
#
# Logging data to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.0009/log.csv
#           Time left:  epoch 0:00:00  total 0:12:50
# actor
#   clip fraction                                        0.139
#   entropy                                               1.04
#   iterations                                              20
#   kl                                                 0.00852
#   loss                                                -0.014
#   std                                                  0.688
#   stop                                                  0.04
# critic
#   iterations                                              80
#   loss                                                  2.94
#   v                                                     19.5
# test
#   action
#     max                                                 2.88
#     mean                                             0.00286
#     min                                                   -3
#     size                                               5,000
#     std                                                0.775
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  423
#     mean                                                 415
#     min                                                  411
#     size                                                   5
#     std                                                 4.31
# train
#   action
#     max                                                 3.71
#     mean                                            -0.00336
#     min                                                -3.22
#     size                                              20,000
#     std                                                0.747
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  412
#     mean                                                 319
#     min                                                  208
#     size                                                  20
#     std                                                 63.4
#   episodes                                                40
#   epoch seconds                                         36.4
#   epoch steps                                          2e+04
#   epochs                                                   2
#   seconds                                               71.8
#   steps                                                4e+04
#   steps per second                                       549
#   worker steps                                         4e+04
#
#           Time left:  epoch 0:00:00  total 0:12:24
# actor
#   clip fraction                                       0.0968
#   entropy                                               1.04
#   iterations                                               4
#   kl                                                 0.00834
#   loss                                              -0.00606
#   std                                                  0.684
#   stop                                                  0.25
# critic
#   iterations                                              80
#   loss                                                  3.11
#   v                                                       39
# test
#   action
#     max                                                  3.4
#     mean                                              0.0251
#     min                                                -3.48
#     size                                               5,000
#     std                                                0.888
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  652
#     mean                                                 630
#     min                                                  605
#     size                                                   5
#     std                                                 15.1
# train
#   action
#     max                                                 3.29
#     mean                                             0.00332
#     min                                                -3.19
#     size                                              20,000
#     std                                                0.823
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  624
#     mean                                                 523
#     min                                                  378
#     size                                                  20
#     std                                                 63.2
#   episodes                                                60
#   epoch seconds                                         34.4
#   epoch steps                                          2e+04
#   epochs                                                   3
#   seconds                                                106
#   steps                                                6e+04
#   steps per second                                       582
#   worker steps                                         6e+04
#
#           Time left:  epoch 0:00:00  total 0:12:02
# actor
#   clip fraction                                        0.138
#   entropy                                               1.03
#   iterations                                            19.4
#   kl                                                 0.00796
#   loss                                               -0.0158
#   std                                                  0.675
#   stop                                                0.0412
# critic
#   iterations                                              80
#   loss                                                  2.54
#   v                                                     57.8
# test
#   action
#     max                                                 3.52
#     mean                                              0.0245
#     min                                                -3.39
#     size                                               5,000
#     std                                                0.942
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  725
#     mean                                                 717
#     min                                                  709
#     size                                                   5
#     std                                                 6.51
# train
#   action
#     max                                                 3.63
#     mean                                               0.021
#     min                                                -3.75
#     size                                              20,000
#     std                                                0.919
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  720
#     mean                                                 671
#     min                                                  620
#     size                                                  20
#     std                                                 30.3
#   episodes                                                80
#   epoch seconds                                           36
#   epoch steps                                          2e+04
#   epochs                                                   4
#   seconds                                                142
#   steps                                                8e+04
#   steps per second                                       555
#   worker steps                                         8e+04
#
#           Time left:  epoch 0:00:00  total 0:11:46
# actor
#   clip fraction                                         0.13
#   entropy                                               0.99
#   iterations                                            53.2
#   kl                                                 0.00967
#   loss                                               -0.0177
#   std                                                  0.651
#   stop                                               0.00752
# critic
#   iterations                                              80
#   loss                                                  1.65
#   v                                                     69.7
# test
#   action
#     max                                                 3.16
#     mean                                               0.014
#     min                                                -3.24
#     size                                               5,000
#     std                                                0.983
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  821
#     mean                                                 804
#     min                                                  794
#     size                                                   5
#     std                                                 9.72
# train
#   action
#     max                                                 3.63
#     mean                                              0.0171
#     min                                                -3.29
#     size                                              20,000
#     std                                                0.965
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  786
#     mean                                                 752
#     min                                                  707
#     size                                                  20
#     std                                                 24.5
#   episodes                                               100
#   epoch seconds                                         38.9
#   epoch steps                                          2e+04
#   epochs                                                   5
#   seconds                                                181
#   steps                                                1e+05
#   steps per second                                       514
#   worker steps                                         1e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.0009/checkpoints/step_100000.pt
#           Time left:  epoch 0:00:00  total 0:11:24
# actor
#   clip fraction                                        0.123
#   entropy                                              0.932
#   iterations                                              64
#   kl                                                 0.00983
#   loss                                               -0.0174
#   std                                                  0.615
#   stop                                               0.00625
# critic
#   iterations                                              80
#   loss                                                 0.788
#   v                                                     78.9
# test
#   action
#     max                                                 3.18
#     mean                                              0.0138
#     min                                                -3.09
#     size                                               5,000
#     std                                                 1.02
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  873
#     mean                                                 860
#     min                                                  842
#     size                                                   5
#     std                                                 10.6
# train
#   action
#     max                                                 3.55
#     mean                                              0.0122
#     min                                                -3.47
#     size                                              20,000
#     std                                                0.995
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  874
#     mean                                                 829
#     min                                                  780
#     size                                                  20
#     std                                                 24.4
#   episodes                                               120
#   epoch seconds                                         39.9
#   epoch steps                                          2e+04
#   epochs                                                   6
#   seconds                                                221
#   steps                                              1.2e+05
#   steps per second                                       501
#   worker steps                                       1.2e+05
#
#           Time left:  epoch 0:00:00  total 0:10:58
# actor
#   clip fraction                                        0.111
#   entropy                                              0.861
#   iterations                                            63.4
#   kl                                                 0.00983
#   loss                                               -0.0173
#   std                                                  0.573
#   stop                                               0.00631
# critic
#   iterations                                              80
#   loss                                                 0.546
#   v                                                     85.2
# test
#   action
#     max                                                 3.17
#     mean                                             0.00979
#     min                                                -2.86
#     size                                               5,000
#     std                                                    1
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  887
#     mean                                                 880
#     min                                                  872
#     size                                                   5
#     std                                                 6.16
# train
#   action
#     max                                                 3.54
#     mean                                               0.012
#     min                                                -3.12
#     size                                              20,000
#     std                                                 1.01
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  897
#     mean                                                 869
#     min                                                  834
#     size                                                  20
#     std                                                 14.9
#   episodes                                               140
#   epoch seconds                                         39.1
#   epoch steps                                          2e+04
#   epochs                                                   7
#   seconds                                                261
#   steps                                              1.4e+05
#   steps per second                                       511
#   worker steps                                       1.4e+05
#
#           Time left:  epoch 0:00:00  total 0:10:22
# actor
#   clip fraction                                       0.0991
#   entropy                                              0.801
#   iterations                                            43.6
#   kl                                                 0.00955
#   loss                                               -0.0164
#   std                                                  0.539
#   stop                                                0.0138
# critic
#   iterations                                              80
#   loss                                                 0.304
#   v                                                     88.9
# test
#   action
#     max                                                 3.32
#     mean                                             0.00926
#     min                                                -3.11
#     size                                               5,000
#     std                                                 1.01
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  911
#     mean                                                 900
#     min                                                  886
#     size                                                   5
#     std                                                 8.81
# train
#   action
#     max                                                 3.14
#     mean                                              0.0139
#     min                                                -3.34
#     size                                              20,000
#     std                                                 1.01
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  905
#     mean                                                 891
#     min                                                  873
#     size                                                  20
#     std                                                 8.69
#   episodes                                               160
#   epoch seconds                                           37
#   epoch steps                                          2e+04
#   epochs                                                   8
#   seconds                                                298
#   steps                                              1.6e+05
#   steps per second                                       541
#   worker steps                                       1.6e+05
#
#           Time left:  epoch 0:00:00  total 0:09:44
# actor
#   clip fraction                                        0.106
#   entropy                                              0.755
#   iterations                                            44.8
#   kl                                                 0.00912
#   loss                                               -0.0167
#   std                                                  0.515
#   stop                                                0.0112
# critic
#   iterations                                              80
#   loss                                                 0.199
#   v                                                     90.9
# test
#   action
#     max                                                 2.85
#     mean                                             0.00705
#     min                                                -2.72
#     size                                               5,000
#     std                                                0.997
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  920
#     mean                                                 903
#     min                                                  885
#     size                                                   5
#     std                                                 12.5
# train
#   action
#     max                                                 3.41
#     mean                                             0.00857
#     min                                                -2.99
#     size                                              20,000
#     std                                                0.995
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  918
#     mean                                                 907
#     min                                                  889
#     size                                                  20
#     std                                                  6.7
#   episodes                                               180
#   epoch seconds                                         36.1
#   epoch steps                                          2e+04
#   epochs                                                   9
#   seconds                                                334
#   steps                                              1.8e+05
#   steps per second                                       553
#   worker steps                                       1.8e+05
#
#           Time left:  epoch 0:00:00  total 0:09:12
# actor
#   clip fraction                                       0.0921
#   entropy                                              0.698
#   iterations                                            48.4
#   kl                                                 0.00835
#   loss                                               -0.0138
#   std                                                  0.487
#   stop                                                0.0124
# critic
#   iterations                                              80
#   loss                                                 0.165
#   v                                                     92.5
# test
#   action
#     max                                                 2.51
#     mean                                             0.00605
#     min                                                -2.86
#     size                                               5,000
#     std                                                0.993
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  934
#     mean                                                 925
#     min                                                  918
#     size                                                   5
#     std                                                 5.51
# train
#   action
#     max                                                 3.13
#     mean                                             0.00553
#     min                                                -2.84
#     size                                              20,000
#     std                                                0.995
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  932
#     mean                                                 918
#     min                                                  897
#     size                                                  20
#     std                                                 9.06
#   episodes                                               200
#   epoch seconds                                         38.9
#   epoch steps                                          2e+04
#   epochs                                                  10
#   seconds                                                373
#   steps                                                2e+05
#   steps per second                                       514
#   worker steps                                         2e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.0009/checkpoints/step_200000.pt
#           Time left:  epoch 0:00:00  total 0:08:37
# actor
#   clip fraction                                       0.0977
#   entropy                                               0.64
#   iterations                                            55.2
#   kl                                                 0.00854
#   loss                                               -0.0156
#   std                                                  0.459
#   stop                                               0.00725
# critic
#   iterations                                              80
#   loss                                                 0.116
#   v                                                     93.8
# test
#   action
#     max                                                 2.57
#     mean                                             0.00308
#     min                                                -2.82
#     size                                               5,000
#     std                                                0.983
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  953
#     mean                                                 938
#     min                                                  920
#     size                                                   5
#     std                                                 10.5
# train
#   action
#     max                                                 2.83
#     mean                                             0.00532
#     min                                                -3.26
#     size                                              20,000
#     std                                                0.985
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  948
#     mean                                                 929
#     min                                                  908
#     size                                                  20
#     std                                                 10.5
#   episodes                                               220
#   epoch seconds                                         38.7
#   epoch steps                                          2e+04
#   epochs                                                  11
#   seconds                                                412
#   steps                                              2.2e+05
#   steps per second                                       517
#   worker steps                                       2.2e+05
#
#           Time left:  epoch 0:00:00  total 0:08:04
# actor
#   clip fraction                                        0.097
#   entropy                                              0.579
#   iterations                                            65.6
#   kl                                                 0.00883
#   loss                                               -0.0163
#   std                                                  0.433
#   stop                                               0.00305
# critic
#   iterations                                              80
#   loss                                                0.0832
#   v                                                       95
# test
#   action
#     max                                                 2.54
#     mean                                             0.00747
#     min                                                -2.66
#     size                                               5,000
#     std                                                0.969
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  958
#     mean                                                 945
#     min                                                  927
#     size                                                   5
#     std                                                 10.3
# train
#   action
#     max                                                 3.21
#     mean                                             0.00937
#     min                                                -2.72
#     size                                              20,000
#     std                                                0.977
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  952
#     mean                                                 941
#     min                                                  923
#     size                                                  20
#     std                                                 6.82
#   episodes                                               240
#   epoch seconds                                           40
#   epoch steps                                          2e+04
#   epochs                                                  12
#   seconds                                                452
#   steps                                              2.4e+05
#   steps per second                                       500
#   worker steps                                       2.4e+05
#
#           Time left:  epoch 0:00:00  total 0:07:28
# actor
#   clip fraction                                       0.0977
#   entropy                                              0.515
#   iterations                                            63.8
#   kl                                                 0.00811
#   loss                                               -0.0145
#   std                                                  0.406
#   stop                                               0.00627
# critic
#   iterations                                              80
#   loss                                                0.0673
#   v                                                       96
# test
#   action
#     max                                                 2.43
#     mean                                             0.00103
#     min                                                -2.63
#     size                                               5,000
#     std                                                0.954
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  959
#     mean                                                 949
#     min                                                  925
#     size                                                   5
#     std                                                 12.4
# train
#   action
#     max                                                 2.76
#     mean                                              0.0081
#     min                                                -2.61
#     size                                              20,000
#     std                                                0.963
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  963
#     mean                                                 949
#     min                                                  926
#     size                                                  20
#     std                                                 9.45
#   episodes                                               260
#   epoch seconds                                         38.6
#   epoch steps                                          2e+04
#   epochs                                                  13
#   seconds                                                491
#   steps                                              2.6e+05
#   steps per second                                       518
#   worker steps                                       2.6e+05
#
#           Time left:  epoch 0:00:00  total 0:06:51
# actor
#   clip fraction                                        0.101
#   entropy                                              0.454
#   iterations                                            49.2
#   kl                                                 0.00905
#   loss                                               -0.0155
#   std                                                  0.382
#   stop                                               0.00813
# ...
#     mean                                             0.00646
#     min                                                -2.45
#     size                                              20,000
#     std                                                0.945
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  977
#     mean                                                 965
#     min                                                  954
#     size                                                  20
#     std                                                 8.16
#   episodes                                               420
#   epoch seconds                                         36.3
#   epoch steps                                          2e+04
#   epochs                                                  21
#   seconds                                                775
#   steps                                              4.2e+05
#   steps per second                                       551
#   worker steps                                       4.2e+05
#
#           Time left:  epoch 0:00:00  total 0:01:49
# actor
#   clip fraction                                       0.0824
#   entropy                                              0.292
#   iterations                                             5.8
#   kl                                                 0.00838
#   loss                                              -0.00444
#   std                                                  0.325
#   stop                                                 0.172
# critic
#   iterations                                              80
#   loss                                                0.0198
#   v                                                     98.3
# test
#   action
#     max                                                 2.29
#     mean                                             0.00543
#     min                                                -2.23
#     size                                               5,000
#     std                                                0.943
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  973
#     mean                                                 964
#     min                                                  956
#     size                                                   5
#     std                                                 5.96
# train
#   action
#     max                                                 2.38
#     mean                                           -0.000356
#     min                                                -2.52
#     size                                              20,000
#     std                                                0.943
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  979
#     mean                                                 964
#     min                                                  951
#     size                                                  20
#     std                                                 9.78
#   episodes                                               440
#   epoch seconds                                           34
#   epoch steps                                          2e+04
#   epochs                                                  22
#   seconds                                                809
#   steps                                              4.4e+05
#   steps per second                                       588
#   worker steps                                       4.4e+05
#
#           Time left:  epoch 0:00:00  total 0:01:13
# actor
#   clip fraction                                       0.0865
#   entropy                                              0.277
#   iterations                                            18.6
#   kl                                                  0.0112
#   loss                                               -0.0111
#   std                                                   0.32
#   stop                                                0.0538
# critic
#   iterations                                              80
#   loss                                                 0.013
#   v                                                     98.6
# test
#   action
#     max                                                 2.33
#     mean                                            -0.00213
#     min                                                -2.11
#     size                                               5,000
#     std                                                0.941
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  983
#     mean                                                 971
#     min                                                  963
#     size                                                   5
#     std                                                  7.5
# train
#   action
#     max                                                 2.35
#     mean                                             0.00126
#     min                                                -2.44
#     size                                              20,000
#     std                                                0.945
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  979
#     mean                                                 971
#     min                                                  963
#     size                                                  20
#     std                                                 4.45
#   episodes                                               460
#   epoch seconds                                         35.5
#   epoch steps                                          2e+04
#   epochs                                                  23
#   seconds                                                845
#   steps                                              4.6e+05
#   steps per second                                       563
#   worker steps                                       4.6e+05
#
#           Time left:  epoch 0:00:00  total 0:00:36
# actor
#   clip fraction                                        0.106
#   entropy                                              0.245
#   iterations                                            40.8
#   kl                                                  0.0104
#   loss                                               -0.0158
#   std                                                   0.31
#   stop                                                0.0147
# critic
#   iterations                                              80
#   loss                                                0.0129
#   v                                                     98.6
# test
#   action
#     max                                                 2.34
#     mean                                             0.00412
#     min                                                -2.19
#     size                                               5,000
#     std                                                0.936
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  981
#     mean                                                 970
#     min                                                  950
#     size                                                   5
#     std                                                 11.4
# train
#   action
#     max                                                 2.39
#     mean                                           -0.000616
#     min                                                -2.41
#     size                                              20,000
#     std                                                0.939
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  978
#     mean                                                 968
#     min                                                  955
#     size                                                  20
#     std                                                 7.63
#   episodes                                               480
#   epoch seconds                                         37.4
#   epoch steps                                          2e+04
#   epochs                                                  24
#   seconds                                                883
#   steps                                              4.8e+05
#   steps per second                                       534
#   worker steps                                       4.8e+05
#
#              Time left:  epoch 0:00:00  total
# actor
#   clip fraction                                        0.103
#   entropy                                              0.212
#   iterations                                            27.2
#   kl                                                 0.00873
#   loss                                               -0.0132
#   std                                                    0.3
#   stop                                                0.0294
# critic
#   iterations                                              80
#   loss                                                0.0109
#   v                                                     98.8
# test
#   action
#     max                                                 2.27
#     mean                                            -0.00351
#     min                                                -2.21
#     size                                               5,000
#     std                                                0.933
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  977
#     mean                                                 967
#     min                                                  959
#     size                                                   5
#     std                                                 5.67
# train
#   action
#     max                                                 2.19
#     mean                                           -2.42e-05
#     min                                                -2.24
#     size                                              20,000
#     std                                                0.935
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  986
#     mean                                                 972
#     min                                                  952
#     size                                                  20
#     std                                                 8.18
#   episodes                                               500
#   epoch seconds                                         35.9
#   epoch steps                                          2e+04
#   epochs                                                  25
#   seconds                                                919
#   steps                                                5e+05
#   steps per second                                       557
#   worker steps                                         5e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.0009/checkpoints/step_500000.pt

# %% [markdown]
# ### Section 2.3 Function to run any model on the environment and generate video

# %% [markdown]
# One of the most fun things about these environments is their visualization. We don't want to just look at the reward to know how good our model is we want to see how well the agent swims. This is particularly important to avoid "reward hacking," where an agent learns to exploit the reward system in ways that are unintended and potentially detrimental to the desired outcomes. Moreover visualizing the agent also help us understand where the model is going wrong.

# %% [markdown]
# Here we have defined a function that will generate the videos of the agent using the input model. The function requires path to the checkpoint folder and the environment you wanna run the trained model on.

# %%
def play_model(path, checkpoint='last',environment='default',seed=None, header=None):

  """
    Plays a model within an environment and renders the gameplay to a video.

    Parameters:
    - path (str): Path to the directory containing the model and checkpoints.
    - checkpoint (str): Specifies which checkpoint to use ('last', 'first', or a specific ID). 'none' indicates no checkpoint.
    - environment (str): The environment to use. 'default' uses the environment specified in the configuration file.
    - seed (int): Optional seed for reproducibility.
    - header (str): Optional Python code to execute before initializing the model, such as importing libraries.
    """

  if checkpoint == 'none':
    # Use no checkpoint, the agent is freshly created.
    checkpoint_path = None
    tonic.logger.log('Not loading any weights')
  else:
    checkpoint_path = os.path.join(path, 'checkpoints')
    if not os.path.isdir(checkpoint_path):
      tonic.logger.error(f'{checkpoint_path} is not a directory')
      checkpoint_path = None

    # List all the checkpoints.
    checkpoint_ids = []
    for file in os.listdir(checkpoint_path):
      if file[:5] == 'step_':
        checkpoint_id = file.split('.')[0]
        checkpoint_ids.append(int(checkpoint_id[5:]))

    if checkpoint_ids:
      if checkpoint == 'last':
        # Use the last checkpoint.
        checkpoint_id = max(checkpoint_ids)
        checkpoint_path = os.path.join(checkpoint_path, f'step_{checkpoint_id}')
      elif checkpoint == 'first':
        # Use the first checkpoint.
        checkpoint_id = min(checkpoint_ids)
        checkpoint_path = os.path.join(checkpoint_path, f'step_{checkpoint_id}')
      else:
        # Use the specified checkpoint.
        checkpoint_id = int(checkpoint)
        if checkpoint_id in checkpoint_ids:
          checkpoint_path = os.path.join(checkpoint_path, f'step_{checkpoint_id}')
        else:
          tonic.logger.error(f'Checkpoint {checkpoint_id} not found in {checkpoint_path}')
          checkpoint_path = None
    else:
      tonic.logger.error(f'No checkpoint found in {checkpoint_path}')
      checkpoint_path = None

  # Load the experiment configuration.
  arguments_path = os.path.join(path, 'config.yaml')
  with open(arguments_path, 'r') as config_file:
    config = yaml.load(config_file, Loader=yaml.FullLoader)
  config = argparse.Namespace(**config)

  # Run the header first, e.g. to load an ML framework.
  try:
    if config.header:
      exec(config.header)
    if header:
      exec(header)
  except:
    pass

  # Build the agent.
  agent = eval(config.agent)

  # Build the environment.
  if environment == 'default':
    environment  = tonic.environments.distribute(lambda: eval(config.environment))
  else:
    environment  = tonic.environments.distribute(lambda: eval(environment))
  if seed is not None:
    environment.seed(seed)

  # Initialize the agent.
  agent.initialize(
    observation_space=environment.observation_space,
    action_space=environment.action_space,
    seed=seed,
  )

  # Load the weights of the agent form a checkpoint.
  if checkpoint_path:
    agent.load(checkpoint_path)

  steps = 0
  test_observations = environment.start()
  frames = [environment.render('rgb_array',camera_id=0, width=640, height=480)[0]]
  score, length = 0, 0

  while True:
      # Select an action.
      actions = agent.test_step(test_observations, steps)
      assert not np.isnan(actions.sum())

      # Take a step in the environment.
      test_observations, infos = environment.step(actions)
      frames.append(environment.render('rgb_array',camera_id=0, width=640, height=480)[0])
      agent.test_update(**infos, steps=steps)

      score += infos['rewards'][0]
      length += 1

      if infos['resets'][0]:
          break
  video_path = os.path.join(path, 'video.mp4')
  print('Reward for the run: ', score)
  return display_video(frames,video_path)

# %% [markdown]
# Let's visualize the agent with a pretrained MLP model. Once you have your pretrained model, you can replace the experiment path to visualize the agent with your model.

# %% [markdown]
# ⏳

# %%
play_model('data/local/experiments/tonic/swimmer-swim/mlp_256')
#play_model('data/local/experiments/tonic/swimmer-swim/pretrained_mlp_ppo')

# %% [markdown]
# ❓

# %% [markdown]
# Try testing the model on a modification of the enviroment it was trained on.
#
#
# *   ***Train on basic swim task and test on a environment with higher viscosity.***
# *   ***Can we train on the basic 6 link swimmer and test on a larger 12 link swimmer?***
# * ***Train the model for a bit on the modified environment and see how quickly the model can adapt to the new environment.***

# %%
# add your code

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_training_models_on_swim_task")

# %% [markdown]
# ---
# ## Section 3: NCAP

# %% [markdown]
# Now that we are familiar with how to train standard models on the swimmer agent let's take a look at NCAP a model that was inspired from the C. elegans motor circuit.
# Our hope with using such models is that they would already have really good priors which should lead to much better transfer, faster learning curves and possibly really good innate performance (zero shot performance).
#
# Check out [NCAP paper](https://arxiv.org/abs/2201.05242) to learn more about the model.

# %%
#@title Paper Illustration

from IPython.display import Image, display
import os
from pathlib import Path

url = "https://github.com/neuromatch/NeuroAI_Course/blob/main/projects/project-notebooks/static/NCAPPaper.png?raw=true"

display(Image(url=url))
# Out:
# <img src="https://github.com/neuromatch/NeuroAI_Course/blob/main/projects/project-notebooks/static/NCAPPaper.png?raw=true"/>

# %% [markdown]
# ### 3.1 NCAP classes

# %% [markdown]
# Now we are going to define ***SwimmerModule*** (NCAP model) and ***SwimmerActor*** (wrapper around NCAP model to make it compatible with tonic) classes.

# %% [markdown]
# #### Section 3.1.1 Defining the constraints

# %%
# ==================================================================================================
# Weight constraints.


def excitatory(w, upper=None):
    return w.clamp(min=0, max=upper)


def inhibitory(w, lower=None):
    return w.clamp(min=lower, max=0)


def unsigned(w, lower=None, upper=None):
    return w if lower is None and upper is None else w.clamp(min=lower, max=upper)


# ==================================================================================================
# Activation constraints.


def graded(x):
    return x.clamp(min=0, max=1)


# ==================================================================================================
# Weight initialization.


def excitatory_uniform(shape=(1,), lower=0., upper=1.):
    assert lower >= 0
    return nn.init.uniform_(nn.Parameter(torch.empty(shape)), a=lower, b=upper)


def inhibitory_uniform(shape=(1,), lower=-1., upper=0.):
    assert upper <= 0
    return nn.init.uniform_(nn.Parameter(torch.empty(shape)), a=lower, b=upper)


def unsigned_uniform(shape=(1,), lower=-1., upper=1.):
    return nn.init.uniform_(nn.Parameter(torch.empty(shape)), a=lower, b=upper)


def excitatory_constant(shape=(1,), value=1.):
    return nn.Parameter(torch.full(shape, value))


def inhibitory_constant(shape=(1,), value=-1.):
    return nn.Parameter(torch.full(shape, value))


def unsigned_constant(shape=(1,), lower=-1., upper=1., p=0.5):
    with torch.no_grad():
        weight = torch.empty(shape).uniform_(0, 1)
        mask = weight < p
        weight[mask] = upper
        weight[~mask] = lower
        return nn.Parameter(weight)

# %% [markdown]
# ***Can you think of more kinds of weight initializations and constraints that might be useful for the swimmer agent?***

# %% [markdown]
# #### Section 3.1.2: Defining the ***SwimmerModule***

# %% [markdown]
# The ***SwimmerModule*** class represents the neural network module inspired by the C. elegans neural circuitry, designed for controlling a robotic swimmer with specific architectural priors, such as proprioception and oscillatory movement patterns.

# %%
class SwimmerModule(nn.Module):
    """C.-elegans-inspired neural circuit architectural prior."""

    def __init__(
            self,
            n_joints: int,
            n_turn_joints: int = 1,
            oscillator_period: int = 60,
            use_weight_sharing: bool = True,
            use_weight_constraints: bool = True,
            use_weight_constant_init: bool = True,
            include_proprioception: bool = True,
            include_head_oscillators: bool = True,
            include_speed_control: bool = False,
            include_turn_control: bool = False,
    ):
        super().__init__()
        self.n_joints = n_joints
        self.n_turn_joints = n_turn_joints
        self.oscillator_period = oscillator_period
        self.include_proprioception = include_proprioception
        self.include_head_oscillators = include_head_oscillators
        self.include_speed_control = include_speed_control
        self.include_turn_control = include_turn_control

        # Log activity
        self.connections_log = []

        # Timestep counter (for oscillations).
        self.timestep = 0

        # Weight sharing switch function.
        self.ws = lambda nonshared, shared: shared if use_weight_sharing else nonshared

        # Weight constraint and init functions.
        if use_weight_constraints:
            self.exc = excitatory
            self.inh = inhibitory
            if use_weight_constant_init:
                exc_param = excitatory_constant
                inh_param = inhibitory_constant
            else:
                exc_param = excitatory_uniform
                inh_param = inhibitory_uniform
        else:
            self.exc = unsigned
            self.inh = unsigned
            if use_weight_constant_init:
                exc_param = inh_param = unsigned_constant
            else:
                exc_param = inh_param = unsigned_uniform

        # Learnable parameters.
        self.params = nn.ParameterDict()
        if use_weight_sharing:
            if self.include_proprioception:
                self.params['bneuron_prop'] = exc_param()
            if self.include_speed_control:
                self.params['bneuron_speed'] = inh_param()
            if self.include_turn_control:
                self.params['bneuron_turn'] = exc_param()
            if self.include_head_oscillators:
                self.params['bneuron_osc'] = exc_param()
            self.params['muscle_ipsi'] = exc_param()
            self.params['muscle_contra'] = inh_param()
        else:
            for i in range(self.n_joints):
                if self.include_proprioception and i > 0:
                    self.params[f'bneuron_d_prop_{i}'] = exc_param()
                    self.params[f'bneuron_v_prop_{i}'] = exc_param()

                if self.include_speed_control:
                    self.params[f'bneuron_d_speed_{i}'] = inh_param()
                    self.params[f'bneuron_v_speed_{i}'] = inh_param()

                if self.include_turn_control and i < self.n_turn_joints:
                    self.params[f'bneuron_d_turn_{i}'] = exc_param()
                    self.params[f'bneuron_v_turn_{i}'] = exc_param()

                if self.include_head_oscillators and i == 0:
                    self.params[f'bneuron_d_osc_{i}'] = exc_param()
                    self.params[f'bneuron_v_osc_{i}'] = exc_param()

                self.params[f'muscle_d_d_{i}'] = exc_param()
                self.params[f'muscle_d_v_{i}'] = inh_param()
                self.params[f'muscle_v_v_{i}'] = exc_param()
                self.params[f'muscle_v_d_{i}'] = inh_param()

    def reset(self):
        self.timestep = 0

    def log_activity(self, activity_type, neuron):
        """Logs an active connection between neurons."""
        self.connections_log.append((self.timestep, activity_type, neuron))

    def forward(
            self,
            joint_pos,
            right_control=None,
            left_control=None,
            speed_control=None,
            timesteps=None,
            log_activity=True,
            log_file='log.txt'
    ):
        """Forward pass.

    Args:
      joint_pos (torch.Tensor): Joint positions in [-1, 1], shape (..., n_joints).
      right_control (torch.Tensor): Right turn control in [0, 1], shape (..., 1).
      left_control (torch.Tensor): Left turn control in [0, 1], shape (..., 1).
      speed_control (torch.Tensor): Speed control in [0, 1], 0 stopped, 1 fastest, shape (..., 1).
      timesteps (torch.Tensor): Timesteps in [0, max_env_steps], shape (..., 1).

    Returns:
      (torch.Tensor): Joint torques in [-1, 1], shape (..., n_joints).
    """

        exc = self.exc
        inh = self.inh
        ws = self.ws

        # Separate into dorsal and ventral sensor values in [0, 1], shape (..., n_joints).
        joint_pos_d = joint_pos.clamp(min=0, max=1)
        joint_pos_v = joint_pos.clamp(min=-1, max=0).neg()

        # Convert speed signal from acceleration into brake.
        if self.include_speed_control:
            assert speed_control is not None
            speed_control = 1 - speed_control.clamp(min=0, max=1)

        joint_torques = []  # [shape (..., 1)]
        for i in range(self.n_joints):
            bneuron_d = bneuron_v = torch.zeros_like(joint_pos[..., 0, None])  # shape (..., 1)

            # B-neurons recieve proprioceptive input from previous joint to propagate waves down the body.
            if self.include_proprioception and i > 0:
                bneuron_d = bneuron_d + joint_pos_d[
                    ..., i - 1, None] * exc(self.params[ws(f'bneuron_d_prop_{i}', 'bneuron_prop')])
                bneuron_v = bneuron_v + joint_pos_v[
                    ..., i - 1, None] * exc(self.params[ws(f'bneuron_v_prop_{i}', 'bneuron_prop')])
                self.log_activity('exc', f'bneuron_d_prop_{i}')
                self.log_activity('exc', f'bneuron_v_prop_{i}')

            # Speed control unit modulates all B-neurons.
            if self.include_speed_control:
                bneuron_d = bneuron_d + speed_control * inh(
                    self.params[ws(f'bneuron_d_speed_{i}', 'bneuron_speed')]
                )
                bneuron_v = bneuron_v + speed_control * inh(
                    self.params[ws(f'bneuron_v_speed_{i}', 'bneuron_speed')]
                )
                self.log_activity('inh', f'bneuron_d_speed_{i}')
                self.log_activity('inh', f'bneuron_v_speed_{i}')

            # Turn control units modulate head B-neurons.
            if self.include_turn_control and i < self.n_turn_joints:
                assert right_control is not None
                assert left_control is not None
                turn_control_d = right_control.clamp(min=0, max=1)  # shape (..., 1)
                turn_control_v = left_control.clamp(min=0, max=1)
                bneuron_d = bneuron_d + turn_control_d * exc(
                    self.params[ws(f'bneuron_d_turn_{i}', 'bneuron_turn')]
                )
                bneuron_v = bneuron_v + turn_control_v * exc(
                    self.params[ws(f'bneuron_v_turn_{i}', 'bneuron_turn')]
                )
                self.log_activity('exc', f'bneuron_d_turn_{i}')
                self.log_activity('exc', f'bneuron_v_turn_{i}')

            # Oscillator units modulate first B-neurons.
            if self.include_head_oscillators and i == 0:
                if timesteps is not None:
                    phase = timesteps.round().remainder(self.oscillator_period)
                    mask = phase < self.oscillator_period // 2
                    oscillator_d = torch.zeros_like(timesteps)  # shape (..., 1)
                    oscillator_v = torch.zeros_like(timesteps)  # shape (..., 1)
                    oscillator_d[mask] = 1.
                    oscillator_v[~mask] = 1.
                else:
                    phase = self.timestep % self.oscillator_period  # in [0, oscillator_period)
                    if phase < self.oscillator_period // 2:
                        oscillator_d, oscillator_v = 1.0, 0.0
                    else:
                        oscillator_d, oscillator_v = 0.0, 1.0
                bneuron_d = bneuron_d + oscillator_d * exc(
                    self.params[ws(f'bneuron_d_osc_{i}', 'bneuron_osc')]
                )
                bneuron_v = bneuron_v + oscillator_v * exc(
                    self.params[ws(f'bneuron_v_osc_{i}', 'bneuron_osc')]
                )

                self.log_activity('exc', f'bneuron_d_osc_{i}')
                self.log_activity('exc', f'bneuron_v_osc_{i}')

            # B-neuron activation.
            bneuron_d = graded(bneuron_d)
            bneuron_v = graded(bneuron_v)

            # Muscles receive excitatory ipsilateral and inhibitory contralateral input.
            muscle_d = graded(
                bneuron_d * exc(self.params[ws(f'muscle_d_d_{i}', 'muscle_ipsi')]) +
                bneuron_v * inh(self.params[ws(f'muscle_d_v_{i}', 'muscle_contra')])
            )
            muscle_v = graded(
                bneuron_v * exc(self.params[ws(f'muscle_v_v_{i}', 'muscle_ipsi')]) +
                bneuron_d * inh(self.params[ws(f'muscle_v_d_{i}', 'muscle_contra')])
            )

            # Joint torque from antagonistic contraction of dorsal and ventral muscles.
            joint_torque = muscle_d - muscle_v
            joint_torques.append(joint_torque)

        self.timestep += 1

        out = torch.cat(joint_torques, -1)  # shape (..., n_joints)
        return out

# %% [markdown]
# #### Section 3.1.3: Defining the ***SwimmerActor*** wrapper

# %% [markdown]
# The ***SwimmerActor*** class acts as a wrapper around the ***SwimmerModule***, managing high-level control signals and observations coming from the environment and passing them to the ***SwimmerModule*** in a suitable format. This class is basically responsible for making the SwimmerModule compatible with the tonic library. If you wish to use any other library to try a algorithm not present in tonic you have to write a new wrapper to make ***SwimmerModule*** compatible with that library.

# %%
class SwimmerActor(nn.Module):
    def __init__(
            self,
            swimmer,
            controller=None,
            distribution=None,
            timestep_transform=(-1, 1, 0, 1000),
    ):
        super().__init__()
        self.swimmer = swimmer
        self.controller = controller
        self.distribution = distribution
        self.timestep_transform = timestep_transform

    def initialize(
            self,
            observation_space,
            action_space,
            observation_normalizer=None,
    ):
        self.action_size = action_space.shape[0]

    def forward(self, observations):
        joint_pos = observations[..., :self.action_size]
        timesteps = observations[..., -1, None]

        # Normalize joint positions by max joint angle (in radians).
        joint_limit = 2 * np.pi / (self.action_size + 1)  # In dm_control, calculated with n_bodies.
        joint_pos = torch.clamp(joint_pos / joint_limit, min=-1, max=1)

        # Convert normalized time signal into timestep.
        if self.timestep_transform:
            low_in, high_in, low_out, high_out = self.timestep_transform
            timesteps = (timesteps - low_in) / (high_in - low_in) * (high_out - low_out) + low_out

        # Generate high-level control signals.
        if self.controller:
            right, left, speed = self.controller(observations)
        else:
            right, left, speed = None, None, None

        # Generate low-level action signals.
        actions = self.swimmer(
            joint_pos,
            timesteps=timesteps,
            right_control=right,
            left_control=left,
            speed_control=speed,
        )

        # Pass through distribution for stochastic policy.
        if self.distribution:
            actions = self.distribution(actions)

        return actions

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_ncap_classes")

# %% [markdown]
# ### 3.2: Train NCAP

# %% [markdown]
# We will now define functions akin to those for MLP we defined in Section 3.2, but tailored for the SwimmerActor model.

# %%
from tonic.torch import models, normalizers
import torch


def ppo_swimmer_model(
        n_joints=5,
        action_noise=0.1,
        critic_sizes=(64, 64),
        critic_activation=nn.Tanh,
        **swimmer_kwargs,
):
    return models.ActorCritic(
        actor=SwimmerActor(
            swimmer=SwimmerModule(n_joints=n_joints, **swimmer_kwargs),
            distribution=lambda x: torch.distributions.normal.Normal(x, action_noise),
        ),
        critic=models.Critic(
            encoder=models.ObservationEncoder(),
            torso=models.MLP(critic_sizes, critic_activation),
            head=models.ValueHead(),
        ),
        observation_normalizer=normalizers.MeanStd(),
    )


def d4pg_swimmer_model(
  n_joints=5,
  critic_sizes=(256, 256),
  critic_activation=nn.ReLU,
  **swimmer_kwargs,
):
  return models.ActorCriticWithTargets(
    actor=SwimmerActor(swimmer=SwimmerModule(n_joints=n_joints, **swimmer_kwargs),),
    critic=models.Critic(
      encoder=models.ObservationActionEncoder(),
      torso=models.MLP(critic_sizes, critic_activation),
      # These values are for the control suite with 0.99 discount.
      head=models.DistributionalValueHead(-150., 150., 51),
    ),
    observation_normalizer=normalizers.MeanStd(),
  )

# %% [markdown]
# ⏳

# %%
#!rm -rf /kaggle/working/tonic/data/local/experiments/tonic/swimmer-swim/ncap_ppo

# %%
# z: train the ncap model with viscosity=0.00002
train('import tonic.torch',
      # 'tonic.torch.agents.D4PG(model=d4pg_swimmer_model(n_joints=5,critic_sizes=(128,128)))',
      'tonic.torch.agents.PPO(model=ppo_swimmer_model(n_joints=5,critic_sizes=(256,256)))',
  'tonic.environments.ControlSuite("swimmer-swim",time_feature=True,task_kwargs = {"viscosity": 0.00002})',
  name = 'ncap_ppo_viscosity_0.00002',   
  trainer = 'tonic.Trainer(steps=int(5e5),save_steps=int(1e5))')
# Out:
# /opt/conda/lib/python3.10/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Config file saved to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.00002/config.yaml
#           Time left:  epoch 0:00:00  total 0:17:48
# actor
#   clip fraction                                        0.013
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00299
#   loss                                             -0.000749
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                  50.8
#   v                                                     33.5
# test
#   action
#     max                                                 1.35
#     mean                                             0.00907
#     min                                                -1.32
#     size                                               5,000
#     std                                                0.806
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  790
#     mean                                                 786
#     min                                                  781
#     size                                                   5
#     std                                                 2.73
# train
#   action
#     max                                                 1.42
#     mean                                              0.0248
#     min                                                -1.38
#     size                                              20,000
#     std                                                0.805
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  788
#     mean                                                 781
#     min                                                  756
#     size                                                  20
#     std                                                 6.99
#   episodes                                                20
#   epoch seconds                                         53.1
#   epoch steps                                          2e+04
#   epochs                                                   1
#   seconds                                               53.1
#   steps                                                2e+04
#   steps per second                                       377
#   worker steps                                         2e+04
#
# Logging data to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.00002/log.csv
#           Time left:  epoch 0:00:00  total 0:19:04
# actor
#   clip fraction                                        0.015
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00185
#   loss                                             -0.000952
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                  3.77
#   v                                                     66.8
# test
#   action
#     max                                                 1.38
#     mean                                              0.0242
#     min                                                -1.35
#     size                                               5,000
#     std                                                0.807
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  788
#     mean                                                 785
#     min                                                  782
#     size                                                   5
#     std                                                 2.61
# train
#   action
#     max                                                 1.37
#     mean                                              0.0249
#     min                                                -1.43
#     size                                              20,000
#     std                                                0.808
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  795
#     mean                                                 784
#     min                                                  773
#     size                                                  20
#     std                                                 5.45
#   episodes                                                40
#   epoch seconds                                         54.9
#   epoch steps                                          2e+04
#   epochs                                                   2
#   seconds                                                108
#   steps                                                4e+04
#   steps per second                                       364
#   worker steps                                         4e+04
#
#           Time left:  epoch 0:00:00  total 0:18:52
# actor
#   clip fraction                                       0.0177
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                  0.0027
#   loss                                              -0.00102
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.577
#   v                                                     76.8
# test
#   action
#     max                                                 1.41
#     mean                                              0.0202
#     min                                                -1.34
#     size                                               5,000
#     std                                                0.819
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  808
#     mean                                                 799
#     min                                                  786
#     size                                                   5
#     std                                                 7.58
# train
#   action
#     max                                                 1.43
#     mean                                              0.0259
#     min                                                -1.41
#     size                                              20,000
#     std                                                0.812
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  802
#     mean                                                 789
#     min                                                  778
#     size                                                  20
#     std                                                 6.88
#   episodes                                                60
#   epoch seconds                                         54.8
#   epoch steps                                          2e+04
#   epochs                                                   3
#   seconds                                                163
#   steps                                                6e+04
#   steps per second                                       365
#   worker steps                                         6e+04
#
#           Time left:  epoch 0:00:00  total 0:18:16
# actor
#   clip fraction                                       0.0452
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00456
#   loss                                               -0.0028
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.182
#   v                                                     80.1
# test
#   action
#     max                                                 1.34
#     mean                                              0.0118
#     min                                                -1.38
#     size                                               5,000
#     std                                                0.825
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  814
#     mean                                                 805
#     min                                                  802
#     size                                                   5
#     std                                                 4.58
# train
#   action
#     max                                                 1.39
#     mean                                              0.0316
#     min                                                -1.42
#     size                                              20,000
#     std                                                0.821
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  812
#     mean                                                 798
#     min                                                  790
#     size                                                  20
#     std                                                 5.14
#   episodes                                                80
#   epoch seconds                                         54.5
#   epoch steps                                          2e+04
#   epochs                                                   4
#   seconds                                                218
#   steps                                                8e+04
#   steps per second                                       367
#   worker steps                                         8e+04
#
#           Time left:  epoch 0:00:00  total 0:17:37
# actor
#   clip fraction                                       0.0321
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00309
#   loss                                              -0.00221
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.132
#   v                                                     81.7
# test
#   action
#     max                                                 1.42
#     mean                                              0.0266
#     min                                                -1.33
#     size                                               5,000
#     std                                                0.832
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  817
#     mean                                                 808
#     min                                                  804
#     size                                                   5
#     std                                                 4.65
# train
#   action
#     max                                                 1.42
#     mean                                              0.0191
#     min                                                -1.39
#     size                                              20,000
#     std                                                0.831
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  818
#     mean                                                 810
#     min                                                  800
#     size                                                  20
#     std                                                  6.1
#   episodes                                               100
#   epoch seconds                                         55.2
#   epoch steps                                          2e+04
#   epochs                                                   5
#   seconds                                                273
#   steps                                                1e+05
#   steps per second                                       362
#   worker steps                                         1e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.00002/checkpoints/step_100000.pt
#           Time left:  epoch 0:00:00  total 0:16:51
# actor
#   clip fraction                                       0.0365
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00241
#   loss                                              -0.00257
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.106
#   v                                                     82.5
# test
#   action
#     max                                                  1.4
#     mean                                              0.0213
#     min                                                -1.41
#     size                                               5,000
#     std                                                0.841
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  823
#     mean                                                 817
#     min                                                  812
#     size                                                   5
#     std                                                 4.92
# train
#   action
#     max                                                 1.44
#     mean                                               0.023
#     min                                                 -1.4
#     size                                              20,000
#     std                                                0.837
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  823
#     mean                                                 813
#     min                                                  802
#     size                                                  20
#     std                                                  5.5
#   episodes                                               120
#   epoch seconds                                         54.9
#   epoch steps                                          2e+04
#   epochs                                                   6
#   seconds                                                328
#   steps                                              1.2e+05
#   steps per second                                       365
#   worker steps                                       1.2e+05
#
#           Time left:  epoch 0:00:00  total 0:16:00
# actor
#   clip fraction                                       0.0381
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00349
#   loss                                              -0.00252
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.072
#   v                                                     83.2
# test
#   action
#     max                                                 1.39
#     mean                                              0.0263
#     min                                                -1.37
#     size                                               5,000
#     std                                                0.851
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  829
#     mean                                                 824
#     min                                                  820
#     size                                                   5
#     std                                                 2.94
# train
#   action
#     max                                                 1.39
#     mean                                               0.023
#     min                                                -1.36
#     size                                              20,000
#     std                                                0.845
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  836
#     mean                                                 819
#     min                                                  810
#     size                                                  20
#     std                                                  5.8
#   episodes                                               140
#   epoch seconds                                         54.4
#   epoch steps                                          2e+04
#   epochs                                                   7
#   seconds                                                382
#   steps                                              1.4e+05
#   steps per second                                       368
#   worker steps                                       1.4e+05
#
#           Time left:  epoch 0:00:00  total 0:15:11
# actor
#   clip fraction                                       0.0322
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00363
#   loss                                              -0.00208
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0647
#   v                                                     83.8
# test
#   action
#     max                                                 1.35
#     mean                                              0.0208
#     min                                                -1.46
#     size                                               5,000
#     std                                                0.859
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  837
#     mean                                                 830
#     min                                                  824
#     size                                                   5
#     std                                                 5.93
# train
#   action
#     max                                                 1.48
#     mean                                              0.0239
#     min                                                -1.41
#     size                                              20,000
#     std                                                0.853
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  830
#     mean                                                 823
#     min                                                  810
#     size                                                  20
#     std                                                 5.03
#   episodes                                               160
#   epoch seconds                                         55.1
#   epoch steps                                          2e+04
#   epochs                                                   8
#   seconds                                                438
#   steps                                              1.6e+05
#   steps per second                                       363
#   worker steps                                       1.6e+05
#
#           Time left:  epoch 0:00:00  total 0:14:18
# actor
#   clip fraction                                       0.0264
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                  0.0031
#   loss                                              -0.00187
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0586
#   v                                                     84.3
# test
#   action
#     max                                                 1.38
#     mean                                              0.0342
#     min                                                -1.41
#     size                                               5,000
#     std                                                0.863
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  834
#     mean                                                 829
#     min                                                  821
#     size                                                   5
#     std                                                 4.55
# train
#   action
#     max                                                 1.42
#     mean                                              0.0367
#     min                                                -1.46
#     size                                              20,000
#     std                                                 0.86
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  837
#     mean                                                 827
#     min                                                  816
#     size                                                  20
#     std                                                 5.23
#   episodes                                               180
#   epoch seconds                                         53.6
#   epoch steps                                          2e+04
#   epochs                                                   9
#   seconds                                                491
#   steps                                              1.8e+05
#   steps per second                                       373
#   worker steps                                       1.8e+05
#
#           Time left:  epoch 0:00:00  total 0:13:27
# actor
#   clip fraction                                       0.0211
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00286
#   loss                                              -0.00143
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0558
#   v                                                       85
# test
#   action
#     max                                                 1.37
#     mean                                              0.0366
#     min                                                -1.35
#     size                                               5,000
#     std                                                0.871
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  845
#     mean                                                 837
#     min                                                  834
#     size                                                   5
#     std                                                 4.11
# train
#   action
#     max                                                 1.38
#     mean                                              0.0293
#     min                                                -1.43
#     size                                              20,000
#     std                                                0.868
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  850
#     mean                                                 836
#     min                                                  826
#     size                                                  20
#     std                                                 5.86
#   episodes                                               200
#   epoch seconds                                         55.6
#   epoch steps                                          2e+04
#   epochs                                                  10
#   seconds                                                547
#   steps                                                2e+05
#   steps per second                                       360
#   worker steps                                         2e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.00002/checkpoints/step_200000.pt
#           Time left:  epoch 0:00:00  total 0:12:35
# actor
#   clip fraction                                       0.0222
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00235
#   loss                                               -0.0014
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0464
#   v                                                     85.3
# test
#   action
#     max                                                 1.37
#     mean                                              0.0216
#     min                                                -1.34
#     size                                               5,000
#     std                                                0.875
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  841
#     mean                                                 839
#     min                                                  836
#     size                                                   5
#     std                                                 2.34
# train
#   action
#     max                                                 1.44
#     mean                                               0.028
#     min                                                -1.41
#     size                                              20,000
#     std                                                0.874
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  851
#     mean                                                 837
#     min                                                  822
#     size                                                  20
#     std                                                 6.28
#   episodes                                               220
#   epoch seconds                                         55.1
#   epoch steps                                          2e+04
#   epochs                                                  11
#   seconds                                                602
#   steps                                              2.2e+05
#   steps per second                                       363
#   worker steps                                       2.2e+05
#
#           Time left:  epoch 0:00:00  total 0:11:42
# actor
#   clip fraction                                       0.0198
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00241
#   loss                                              -0.00132
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0558
#   v                                                     85.9
# test
#   action
#     max                                                 1.35
#     mean                                              0.0183
#     min                                                -1.33
#     size                                               5,000
#     std                                                0.884
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  850
#     mean                                                 840
#     min                                                  812
#     size                                                   5
#     std                                                 14.1
# train
#   action
#     max                                                 1.43
#     mean                                              0.0255
#     min                                                -1.43
#     size                                              20,000
#     std                                                0.879
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  852
#     mean                                                 843
#     min                                                  831
#     size                                                  20
#     std                                                 5.87
#   episodes                                               240
#   epoch seconds                                         55.1
#   epoch steps                                          2e+04
#   epochs                                                  12
#   seconds                                                657
#   steps                                              2.4e+05
#   steps per second                                       363
#   worker steps                                       2.4e+05
#
#           Time left:  epoch 0:00:00  total 0:10:49
# actor
#   clip fraction                                       0.0196
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00257
#   loss                                              -0.00142
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0449
#   v                                                     86.1
# test
#   action
#     max                                                 1.36
#     mean                                              0.0432
#     min                                                -1.35
#     size                                               5,000
#     std                                                0.887
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  846
#     mean                                                 838
#     min                                                  817
#     size                                                   5
#     std                                                 11.2
# train
#   action
#     max                                                 1.42
#     mean                                              0.0303
#     min                                                -1.39
#     size                                              20,000
#     std                                                0.884
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  853
#     mean                                                 843
#     min                                                  819
#     size                                                  20
#     std                                                 6.81
#   episodes                                               260
#   epoch seconds                                         54.6
#   epoch steps                                          2e+04
#   epochs                                                  13
#   seconds                                                712
#   steps                                              2.6e+05
#   steps per second                                       366
#   worker steps                                       2.6e+05
#
#           Time left:  epoch 0:00:00  total 0:09:55
# actor
#   clip fraction                                       0.0112
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00185
#   loss                                             -0.000919
#   std                                                    0.1
#   stop                                                     0
# ...
#     mean                                              0.0287
#     min                                                -1.39
#     size                                              20,000
#     std                                                 0.91
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  863
#     mean                                                 855
#     min                                                  847
#     size                                                  20
#     std                                                 3.74
#   episodes                                               420
#   epoch seconds                                         53.6
#   epoch steps                                          2e+04
#   epochs                                                  21
#   seconds                                           1.15e+03
#   steps                                              4.2e+05
#   steps per second                                       373
#   worker steps                                       4.2e+05
#
#           Time left:  epoch 0:00:00  total 0:02:43
# actor
#   clip fraction                                       0.0101
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00145
#   loss                                             -0.000681
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0319
#   v                                                     87.4
# test
#   action
#     max                                                 1.45
#     mean                                                0.02
#     min                                                -1.33
#     size                                               5,000
#     std                                                0.916
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  869
#     mean                                                 866
#     min                                                  862
#     size                                                   5
#     std                                                 2.72
# train
#   action
#     max                                                 1.37
#     mean                                              0.0353
#     min                                                -1.38
#     size                                              20,000
#     std                                                0.912
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  862
#     mean                                                 855
#     min                                                  843
#     size                                                  20
#     std                                                 5.51
#   episodes                                               440
#   epoch seconds                                         54.6
#   epoch steps                                          2e+04
#   epochs                                                  22
#   seconds                                            1.2e+03
#   steps                                              4.4e+05
#   steps per second                                       366
#   worker steps                                       4.4e+05
#
#           Time left:  epoch 0:00:00  total 0:01:48
# actor
#   clip fraction                                      0.00161
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                0.000928
#   loss                                             -0.000193
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0308
#   v                                                     87.5
# test
#   action
#     max                                                  1.4
#     mean                                              0.0359
#     min                                                -1.47
#     size                                               5,000
#     std                                                0.915
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  868
#     mean                                                 861
#     min                                                  854
#     size                                                   5
#     std                                                 5.18
# train
#   action
#     max                                                 1.41
#     mean                                              0.0324
#     min                                                -1.42
#     size                                              20,000
#     std                                                0.914
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  870
#     mean                                                 856
#     min                                                  836
#     size                                                  20
#     std                                                 7.69
#   episodes                                               460
#   epoch seconds                                         55.1
#   epoch steps                                          2e+04
#   epochs                                                  23
#   seconds                                           1.26e+03
#   steps                                              4.6e+05
#   steps per second                                       363
#   worker steps                                       4.6e+05
#
#           Time left:  epoch 0:00:00  total 0:00:54
# actor
#   clip fraction                                       0.0124
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00176
#   loss                                             -0.000794
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0392
#   v                                                     87.6
# test
#   action
#     max                                                 1.36
#     mean                                              0.0326
#     min                                                -1.36
#     size                                               5,000
#     std                                                0.918
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  858
#     mean                                                 856
#     min                                                  853
#     size                                                   5
#     std                                                 1.97
# train
#   action
#     max                                                 1.42
#     mean                                               0.025
#     min                                                -1.41
#     size                                              20,000
#     std                                                0.919
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  868
#     mean                                                 858
#     min                                                  838
#     size                                                  20
#     std                                                 8.54
#   episodes                                               480
#   epoch seconds                                         55.3
#   epoch steps                                          2e+04
#   epochs                                                  24
#   seconds                                           1.31e+03
#   steps                                              4.8e+05
#   steps per second                                       362
#   worker steps                                       4.8e+05
#
#              Time left:  epoch 0:00:00  total
# actor
#   clip fraction                                      0.00125
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00101
#   loss                                             -0.000222
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0307
#   v                                                     87.7
# test
#   action
#     max                                                 1.41
#     mean                                              0.0434
#     min                                                -1.47
#     size                                               5,000
#     std                                                0.921
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  869
#     mean                                                 853
#     min                                                  836
#     size                                                   5
#     std                                                 13.9
# train
#   action
#     max                                                 1.44
#     mean                                              0.0292
#     min                                                -1.41
#     size                                              20,000
#     std                                                0.921
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  867
#     mean                                                 858
#     min                                                  850
#     size                                                  20
#     std                                                 4.69
#   episodes                                               500
#   epoch seconds                                         55.4
#   epoch steps                                          2e+04
#   epochs                                                  25
#   seconds                                           1.37e+03
#   steps                                                5e+05
#   steps per second                                       361
#   worker steps                                         5e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.00002/checkpoints/step_500000.pt

# %%
# z: train the ncap model with viscosity=0.0009
train('import tonic.torch',
      # 'tonic.torch.agents.D4PG(model=d4pg_swimmer_model(n_joints=5,critic_sizes=(128,128)))',
      'tonic.torch.agents.PPO(model=ppo_swimmer_model(n_joints=5,critic_sizes=(256,256)))',
  'tonic.environments.ControlSuite("swimmer-swim",time_feature=True,task_kwargs = {"viscosity": 0.0009})',
  name = 'ncap_ppo_viscosity_0.0009',   
  trainer = 'tonic.Trainer(steps=int(5e5),save_steps=int(1e5))')
# Out:
# /opt/conda/lib/python3.10/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Config file saved to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.0009/config.yaml
#           Time left:  epoch 0:00:00  total 0:18:07
# actor
#   clip fraction                                       0.0248
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00324
#   loss                                              -0.00152
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                  49.3
#   v                                                     33.1
# test
#   action
#     max                                                 1.35
#     mean                                              0.0154
#     min                                                -1.31
#     size                                               5,000
#     std                                                0.804
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  781
#     mean                                                 777
#     min                                                  771
#     size                                                   5
#     std                                                  3.5
# train
#   action
#     max                                                 1.43
#     mean                                              0.0173
#     min                                                -1.38
#     size                                              20,000
#     std                                                0.805
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  783
#     mean                                                 775
#     min                                                  765
#     size                                                  20
#     std                                                 4.29
#   episodes                                                20
#   epoch seconds                                         53.9
#   epoch steps                                          2e+04
#   epochs                                                   1
#   seconds                                               53.9
#   steps                                                2e+04
#   steps per second                                       371
#   worker steps                                         2e+04
#
# Logging data to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.0009/log.csv
#           Time left:  epoch 0:00:00  total 0:19:20
# actor
#   clip fraction                                       0.0166
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00332
#   loss                                              -0.00109
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                  3.65
#   v                                                     66.3
# test
#   action
#     max                                                 1.36
#     mean                                              0.0166
#     min                                                -1.34
#     size                                               5,000
#     std                                                0.804
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  789
#     mean                                                 779
#     min                                                  768
#     size                                                   5
#     std                                                 7.34
# train
#   action
#     max                                                 1.37
#     mean                                              0.0226
#     min                                                -1.42
#     size                                              20,000
#     std                                                0.806
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  793
#     mean                                                 781
#     min                                                  770
#     size                                                  20
#     std                                                 4.82
#   episodes                                                40
#   epoch seconds                                         55.5
#   epoch steps                                          2e+04
#   epochs                                                   2
#   seconds                                                109
#   steps                                                4e+04
#   steps per second                                       360
#   worker steps                                         4e+04
#
#           Time left:  epoch 0:00:00  total 0:19:08
# actor
#   clip fraction                                        0.028
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00275
#   loss                                              -0.00161
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                   0.6
#   v                                                     76.3
# test
#   action
#     max                                                 1.41
#     mean                                              0.0313
#     min                                                -1.34
#     size                                               5,000
#     std                                                0.813
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  798
#     mean                                                 789
#     min                                                  782
#     size                                                   5
#     std                                                 5.53
# train
#   action
#     max                                                 1.43
#     mean                                              0.0283
#     min                                                -1.41
#     size                                              20,000
#     std                                                0.808
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  793
#     mean                                                 783
#     min                                                  765
#     size                                                  20
#     std                                                 7.27
#   episodes                                                60
#   epoch seconds                                         55.9
#   epoch steps                                          2e+04
#   epochs                                                   3
#   seconds                                                165
#   steps                                                6e+04
#   steps per second                                       358
#   worker steps                                         6e+04
#
#           Time left:  epoch 0:00:00  total 0:18:33
# actor
#   clip fraction                                       0.0363
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00366
#   loss                                              -0.00246
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.193
#   v                                                     79.5
# test
#   action
#     max                                                 1.32
#     mean                                              0.0139
#     min                                                -1.35
#     size                                               5,000
#     std                                                0.819
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  802
#     mean                                                 798
#     min                                                  794
#     size                                                   5
#     std                                                 3.27
# train
#   action
#     max                                                 1.39
#     mean                                              0.0212
#     min                                                -1.42
#     size                                              20,000
#     std                                                0.816
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  810
#     mean                                                 793
#     min                                                  782
#     size                                                  20
#     std                                                 7.02
#   episodes                                                80
#   epoch seconds                                           55
#   epoch steps                                          2e+04
#   epochs                                                   4
#   seconds                                                221
#   steps                                                8e+04
#   steps per second                                       363
#   worker steps                                         8e+04
#
#           Time left:  epoch 0:00:00  total 0:17:50
# actor
#   clip fraction                                       0.0357
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00559
#   loss                                              -0.00229
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.152
#   v                                                     80.8
# test
#   action
#     max                                                 1.42
#     mean                                              0.0245
#     min                                                -1.33
#     size                                               5,000
#     std                                                0.814
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  811
#     mean                                                 800
#     min                                                  789
#     size                                                   5
#     std                                                  7.2
# train
#   action
#     max                                                 1.38
#     mean                                              0.0248
#     min                                                -1.38
#     size                                              20,000
#     std                                                0.819
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  806
#     mean                                                 798
#     min                                                  781
#     size                                                  20
#     std                                                 6.74
#   episodes                                               100
#   epoch seconds                                         55.5
#   epoch steps                                          2e+04
#   epochs                                                   5
#   seconds                                                276
#   steps                                                1e+05
#   steps per second                                       360
#   worker steps                                         1e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.0009/checkpoints/step_100000.pt
#           Time left:  epoch 0:00:00  total 0:17:04
# actor
#   clip fraction                                       0.0449
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00292
#   loss                                              -0.00291
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.152
#   v                                                     81.5
# test
#   action
#     max                                                 1.35
#     mean                                              0.0206
#     min                                                -1.41
#     size                                               5,000
#     std                                                0.819
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  814
#     mean                                                 809
#     min                                                  802
#     size                                                   5
#     std                                                  4.1
# train
#   action
#     max                                                 1.45
#     mean                                              0.0313
#     min                                                -1.37
#     size                                              20,000
#     std                                                0.819
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  821
#     mean                                                 801
#     min                                                  789
#     size                                                  20
#     std                                                 7.23
#   episodes                                               120
#   epoch seconds                                         55.8
#   epoch steps                                          2e+04
#   epochs                                                   6
#   seconds                                                332
#   steps                                              1.2e+05
#   steps per second                                       358
#   worker steps                                       1.2e+05
#
#           Time left:  epoch 0:00:00  total 0:16:13
# actor
#   clip fraction                                       0.0393
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00395
#   loss                                              -0.00317
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0963
#   v                                                     82.3
# test
#   action
#     max                                                 1.36
#     mean                                               0.031
#     min                                                -1.37
#     size                                               5,000
#     std                                                0.815
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  820
#     mean                                                 810
#     min                                                  795
#     size                                                   5
#     std                                                 8.79
# train
#   action
#     max                                                 1.39
#     mean                                              0.0284
#     min                                                -1.35
#     size                                              20,000
#     std                                                0.815
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  821
#     mean                                                 809
#     min                                                  801
#     size                                                  20
#     std                                                 5.38
#   episodes                                               140
#   epoch seconds                                           55
#   epoch steps                                          2e+04
#   epochs                                                   7
#   seconds                                                387
#   steps                                              1.4e+05
#   steps per second                                       364
#   worker steps                                       1.4e+05
#
#           Time left:  epoch 0:00:00  total 0:15:22
# actor
#   clip fraction                                       0.0549
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00526
#   loss                                              -0.00371
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                  0.12
#   v                                                     82.9
# test
#   action
#     max                                                 1.35
#     mean                                               0.027
#     min                                                -1.35
#     size                                               5,000
#     std                                                 0.81
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  822
#     mean                                                 821
#     min                                                  819
#     size                                                   5
#     std                                                 1.05
# train
#   action
#     max                                                 1.38
#     mean                                              0.0287
#     min                                                -1.37
#     size                                              20,000
#     std                                                0.813
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  829
#     mean                                                 815
#     min                                                  791
#     size                                                  20
#     std                                                 8.68
#   episodes                                               160
#   epoch seconds                                         55.6
#   epoch steps                                          2e+04
#   epochs                                                   8
#   seconds                                                443
#   steps                                              1.6e+05
#   steps per second                                       359
#   worker steps                                       1.6e+05
#
#           Time left:  epoch 0:00:00  total 0:14:27
# actor
#   clip fraction                                       0.0462
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00394
#   loss                                              -0.00323
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.165
#   v                                                     83.4
# test
#   action
#     max                                                 1.32
#     mean                                              0.0172
#     min                                                -1.38
#     size                                               5,000
#     std                                                0.805
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  834
#     mean                                                 823
#     min                                                  816
#     size                                                   5
#     std                                                 6.76
# train
#   action
#     max                                                 1.42
#     mean                                              0.0251
#     min                                                -1.46
#     size                                              20,000
#     std                                                0.807
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  838
#     mean                                                 821
#     min                                                  811
#     size                                                  20
#     std                                                 6.87
#   episodes                                               180
#   epoch seconds                                         53.6
#   epoch steps                                          2e+04
#   epochs                                                   9
#   seconds                                                497
#   steps                                              1.8e+05
#   steps per second                                       373
#   worker steps                                       1.8e+05
#
#           Time left:  epoch 0:00:00  total 0:13:35
# actor
#   clip fraction                                       0.0483
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00417
#   loss                                              -0.00373
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.151
#   v                                                     83.9
# test
#   action
#     max                                                 1.36
#     mean                                             0.00347
#     min                                                -1.35
#     size                                               5,000
#     std                                                0.801
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  839
#     mean                                                 827
#     min                                                  816
#     size                                                   5
#     std                                                 8.64
# train
#   action
#     max                                                 1.39
#     mean                                               0.022
#     min                                                -1.43
#     size                                              20,000
#     std                                                0.801
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  835
#     mean                                                 822
#     min                                                  811
#     size                                                  20
#     std                                                  6.6
#   episodes                                               200
#   epoch seconds                                         55.1
#   epoch steps                                          2e+04
#   epochs                                                  10
#   seconds                                                552
#   steps                                                2e+05
#   steps per second                                       363
#   worker steps                                         2e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.0009/checkpoints/step_200000.pt
#           Time left:  epoch 0:00:00  total 0:12:42
# actor
#   clip fraction                                       0.0435
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00476
#   loss                                              -0.00368
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.122
#   v                                                     84.2
# test
#   action
#     max                                                 1.37
#     mean                                              0.0194
#     min                                                -1.34
#     size                                               5,000
#     std                                                0.794
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  841
#     mean                                                 834
#     min                                                  823
#     size                                                   5
#     std                                                  6.8
# train
#   action
#     max                                                 1.44
#     mean                                              0.0154
#     min                                                -1.35
#     size                                              20,000
#     std                                                0.796
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  840
#     mean                                                 828
#     min                                                  815
#     size                                                  20
#     std                                                 6.04
#   episodes                                               220
#   epoch seconds                                         55.7
#   epoch steps                                          2e+04
#   epochs                                                  11
#   seconds                                                608
#   steps                                              2.2e+05
#   steps per second                                       359
#   worker steps                                       2.2e+05
#
#           Time left:  epoch 0:00:00  total 0:11:48
# actor
#   clip fraction                                       0.0439
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00475
#   loss                                              -0.00344
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.111
#   v                                                       85
# test
#   action
#     max                                                 1.35
#     mean                                              0.0383
#     min                                                -1.34
#     size                                               5,000
#     std                                                 0.79
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  851
#     mean                                                 838
#     min                                                  821
#     size                                                   5
#     std                                                 12.7
# train
#   action
#     max                                                 1.34
#     mean                                              0.0167
#     min                                                -1.43
#     size                                              20,000
#     std                                                 0.79
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  852
#     mean                                                 836
#     min                                                  820
#     size                                                  20
#     std                                                 8.48
#   episodes                                               240
#   epoch seconds                                         54.5
#   epoch steps                                          2e+04
#   epochs                                                  12
#   seconds                                                662
#   steps                                              2.4e+05
#   steps per second                                       367
#   worker steps                                       2.4e+05
#
#           Time left:  epoch 0:00:00  total 0:10:54
# actor
#   clip fraction                                       0.0437
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00383
#   loss                                              -0.00335
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.105
#   v                                                     85.8
# test
#   action
#     max                                                 1.36
#     mean                                             0.00898
#     min                                                -1.35
#     size                                               5,000
#     std                                                0.783
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  859
#     mean                                                 853
#     min                                                  845
#     size                                                   5
#     std                                                 5.21
# train
#   action
#     max                                                 1.42
#     mean                                              0.0144
#     min                                                -1.36
#     size                                              20,000
#     std                                                0.787
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  859
#     mean                                                 847
#     min                                                  828
#     size                                                  20
#     std                                                 7.81
#   episodes                                               260
#   epoch seconds                                         55.3
#   epoch steps                                          2e+04
#   epochs                                                  13
#   seconds                                                718
#   steps                                              2.6e+05
#   steps per second                                       362
#   worker steps                                       2.6e+05
#
#           Time left:  epoch 0:00:00  total 0:10:00
# actor
#   clip fraction                                       0.0608
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00631
#   loss                                               -0.0042
#   std                                                    0.1
#   stop                                                     0
# ...
#     mean                                              0.0136
#     min                                                -1.39
#     size                                              20,000
#     std                                                0.782
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  901
#     mean                                                 886
#     min                                                  850
#     size                                                  20
#     std                                                 11.5
#   episodes                                               420
#   epoch seconds                                         54.4
#   epoch steps                                          2e+04
#   epochs                                                  21
#   seconds                                           1.16e+03
#   steps                                              4.2e+05
#   steps per second                                       368
#   worker steps                                       4.2e+05
#
#           Time left:  epoch 0:00:00  total 0:02:43
# actor
#   clip fraction                                       0.0541
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00308
#   loss                                              -0.00259
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0576
#   v                                                     90.9
# test
#   action
#     max                                                 1.36
#     mean                                               0.018
#     min                                                -1.33
#     size                                               5,000
#     std                                                0.801
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  906
#     mean                                                 887
#     min                                                  832
#     size                                                   5
#     std                                                 27.6
# train
#   action
#     max                                                 1.35
#     mean                                              0.0236
#     min                                                -1.38
#     size                                              20,000
#     std                                                0.794
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  910
#     mean                                                 887
#     min                                                  808
#     size                                                  20
#     std                                                 19.9
#   episodes                                               440
#   epoch seconds                                           54
#   epoch steps                                          2e+04
#   epochs                                                  22
#   seconds                                           1.21e+03
#   steps                                              4.4e+05
#   steps per second                                       371
#   worker steps                                       4.4e+05
#
#           Time left:  epoch 0:00:00  total 0:01:49
# actor
#   clip fraction                                       0.0292
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00323
#   loss                                              -0.00125
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0568
#   v                                                     91.4
# test
#   action
#     max                                                 1.35
#     mean                                            -0.00266
#     min                                                -1.47
#     size                                               5,000
#     std                                                0.804
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  906
#     mean                                                 898
#     min                                                  881
#     size                                                   5
#     std                                                 9.18
# train
#   action
#     max                                                 1.39
#     mean                                              0.0272
#     min                                                -1.42
#     size                                              20,000
#     std                                                0.801
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  913
#     mean                                                 891
#     min                                                  849
#     size                                                  20
#     std                                                 13.8
#   episodes                                               460
#   epoch seconds                                         54.3
#   epoch steps                                          2e+04
#   epochs                                                  23
#   seconds                                           1.26e+03
#   steps                                              4.6e+05
#   steps per second                                       368
#   worker steps                                       4.6e+05
#
#           Time left:  epoch 0:00:00  total 0:00:54
# actor
#   clip fraction                                       0.0264
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                  0.0025
#   loss                                              -0.00158
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                 0.045
#   v                                                     91.8
# test
#   action
#     max                                                 1.35
#     mean                                              0.0508
#     min                                                -1.36
#     size                                               5,000
#     std                                                0.812
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  914
#     mean                                                 875
#     min                                                  839
#     size                                                   5
#     std                                                 29.3
# train
#   action
#     max                                                 1.42
#     mean                                              0.0191
#     min                                                -1.43
#     size                                              20,000
#     std                                                0.808
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  911
#     mean                                                 899
#     min                                                  884
#     size                                                  20
#     std                                                 7.26
#   episodes                                               480
#   epoch seconds                                         55.1
#   epoch steps                                          2e+04
#   epochs                                                  24
#   seconds                                           1.32e+03
#   steps                                              4.8e+05
#   steps per second                                       363
#   worker steps                                       4.8e+05
#
#              Time left:  epoch 0:00:00  total
# actor
#   clip fraction                                       0.0274
#   entropy                                             -0.884
#   iterations                                              80
#   kl                                                 0.00295
#   loss                                               -0.0012
#   std                                                    0.1
#   stop                                                     0
# critic
#   iterations                                              80
#   loss                                                0.0489
#   v                                                     91.9
# test
#   action
#     max                                                 1.38
#     mean                                               0.023
#     min                                                -1.47
#     size                                               5,000
#     std                                                0.812
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                   5
#     std                                                    0
#   episode score
#     max                                                  913
#     mean                                                 897
#     min                                                  888
#     size                                                   5
#     std                                                 8.19
# train
#   action
#     max                                                 1.44
#     mean                                               0.018
#     min                                                -1.41
#     size                                              20,000
#     std                                                0.815
#   episode length
#     max                                                1,000
#     mean                                               1e+03
#     min                                                1,000
#     size                                                  20
#     std                                                    0
#   episode score
#     max                                                  917
#     mean                                                 899
#     min                                                  841
#     size                                                  20
#     std                                                 15.4
#   episodes                                               500
#   epoch seconds                                         54.8
#   epoch steps                                          2e+04
#   epochs                                                  25
#   seconds                                           1.37e+03
#   steps                                                5e+05
#   steps per second                                       365
#   worker steps                                         5e+05
#
#
# Saving weights to data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.0009/checkpoints/step_500000.pt

# %%
train('import tonic.torch',
      # 'tonic.torch.agents.D4PG(model=d4pg_swimmer_model(n_joints=5,critic_sizes=(128,128)))',
      'tonic.torch.agents.PPO(model=ppo_swimmer_model(n_joints=5,critic_sizes=(256,256)))',
  'tonic.environments.ControlSuite("swimmer-swim",time_feature=True)',
  name = 'ncap_ppo',
  #trainer = 'tonic.Trainer(steps=int(1e5),save_steps=int(5e4))') 
      
  # z: change the steps of NCAP to be similar to MLP in favor of a better comparison at the end    
  trainer = 'tonic.Trainer(steps=int(5e5),save_steps=int(1e5))')

# %% [markdown]
# Let's visualize the trained NCAP agent in the environment.

# %% [markdown]
# ⏳

# %%
play_model('data/local/experiments/tonic/swimmer-swim/ncap_ppo')
#play_model('data/local/experiments/tonic/swimmer-swim/pretrained_ncap_ppo')

# %% [markdown]
# ❓

# %% [markdown]
# ***This architecture was designed using the C. elegans motor circuit that can swim right at birth i.e it should already have really good priors. Can you try visualizing an agent with an untrained NCAP model. Can it swim?***

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_train_ncap")

# %% [markdown]
# ### 3.3 Plot perfomance

# %% [markdown]
# Now we are going to visualize performance of our model

# %%
def plot_performance(paths, ax=None,title='Model Performance'):
    """
    Plots the performance of multiple models on the same axes using Seaborn for styling.

    Reads CSV log files from specified paths and plots the mean episode scores
    achieved during testing against the cumulative time steps for each model.
    The plot uses a logarithmic scale for the x-axis to better display the progression
    over a wide range of steps. Each line's legend is set to the name of the last folder
    in the path, representing the model's name. Seaborn styles are applied for enhanced visualization.

    Parameters:
    - paths (list of str): Paths to the experiment directories.
    - ax (matplotlib.axes.Axes, optional): A matplotlib axis object to plot on. If None,
      a new figure and axis are created.
    """
    # Set the Seaborn style
    sns.set(style="whitegrid")
    colors = sns.color_palette("colorblind")  # Colorblind-friendly palette

    if ax is None:
        fig, ax = plt.subplots()

    for index, path in enumerate(paths):
        # Extract the model name from the path
        model_name = os.path.basename(path.rstrip('/'))

        # Load data
        df = pd.read_csv(os.path.join(path, 'log.csv'))
        scores = df['test/episode_score/mean']
        lengths = df['test/episode_length/mean']
        steps = np.cumsum(lengths)
        sns.lineplot(x=steps, y=scores, ax=ax, label=model_name, color=colors[index % len(colors)])

    ax.set_xscale('log')
    ax.set_xlabel('Cumulative Time Steps')
    ax.set_ylabel('Max Episode Score')
    ax.legend()
    ax.set_title(title)

# %%
fig, ax = plt.subplots()

#Replace the paths with the path to models you trained to plot their performance.
paths = [
#     'data/local/experiments/tonic/swimmer-swim/pretrained_ncap_ppo',
#     'data/local/experiments/tonic/swimmer-swim/pretrained_mlp_ppo',
      'data/local/experiments/tonic/swimmer-swim/mlp_256',
      'data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.0009',
      'data/local/experiments/tonic/swimmer-swim/mlp_256_viscosity_0.00002',
      'data/local/experiments/tonic/swimmer-swim/ncap_ppo',
      'data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.0009',
      'data/local/experiments/tonic/swimmer-swim/ncap_ppo_viscosity_0.00002'
]
plot_performance(paths, ax=ax, title='MLP v/s NCAP')
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ❓

# %% [markdown]
# * ***Compare the performance and learning curve of NCAP to MLP for the basic swimmer agent.***
# * ***Try testing the model on a modification of the environment (e.g., the 12-link swimmer) it was trained on.***
# * ***What happens if we remove certain weight constraints (e.g., sign constraint) from the NCAP model?***

# %%
# add your code

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_plot_performance")

# %% [markdown]
# ---
# ## Section 4: Visualizing the sparse network

# %% [markdown]
# Given the importance of architectural choices in our project we have provided a function which can visualize the network architecture. This includes the ability to render the NCAP network, representing the C. Elegans connectome.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np


def draw_network(mode='NCAP', N=2, include_speed_control=False, include_turn_control=False):

    """
    Draws a network graph for a swimmer model based on either NCAP or MLP architecture.

    Parameters:
    - mode (str): Determines the architecture type ('NCAP' or 'MLP'). Defaults to 'NCAP'.
    - N (int): Number of joints in the swimmer model. Defaults to 2.
    - include_speed_control (bool): If True, includes nodes for speed control in the graph.
    - include_turn_control (bool): If True, includes nodes for turn control in the graph.
    """


    G = nx.DiGraph()

    n=2+N*4

    nodes =dict()

    if include_speed_control:
      nodes['1-s'] = n+7
    if include_turn_control:
      nodes['r'] = n+5
      nodes['l'] = n+3

    nodes['o'] = n-1
    nodes['$o^d$'] = n-0
    nodes['$o^v$']= n-2

    custom_node_positions = {}
    custom_node_positions['o'] = (1, nodes['o'])
    custom_node_positions['$o^d$'] = (1.5, nodes['$o^d$'])
    custom_node_positions['$o^v$'] = (1.5, nodes['$o^v$'])


    if include_speed_control:
      custom_node_positions['1-s'] = (1.5, nodes['1-s'])
    if include_turn_control:
      custom_node_positions['r'] = (1.5, nodes['r'])
      custom_node_positions['l'] = (1.5, nodes['l'])

    for i in range(1,N+1):
      nodes[f'$q_{i}$'] = 4*(N-i) + 1
      nodes[f'$q^d_{i}$'] = 4*(N-i) + 2
      nodes[f'$q^v_{i}$'] = 4*(N-i)
      nodes[f'$b^d_{i}$'] = 4*(N-i) + 2
      nodes[f'$b^v_{i}$'] = 4*(N-i)
      nodes[f'$m^d_{i}$'] = 4*(N-i) + 2
      nodes[f'$m^v_{i}$'] = 4*(N-i)
      nodes['$\overset{..}{q}$' + f'$_{i}$'] = 4*(N-i) + 1

      custom_node_positions[f'$q_{i}$'] = (1, nodes[f'$q_{i}$'])
      custom_node_positions[f'$q^d_{i}$'] = (1.5, nodes[f'$q^d_{i}$'])
      custom_node_positions[f'$q^v_{i}$'] = (1.5, nodes[f'$q^v_{i}$'])
      custom_node_positions[f'$b^d_{i}$'] = (2, nodes[f'$b^d_{i}$'])
      custom_node_positions[f'$b^v_{i}$'] = (2, nodes[f'$b^v_{i}$'])
      custom_node_positions[f'$m^d_{i}$'] = (2.5, nodes[f'$m^d_{i}$'])
      custom_node_positions[f'$m^v_{i}$'] = (2.5, nodes[f'$m^v_{i}$'])
      custom_node_positions['$\overset{..}{q}$' + f'$_{i}$'] = (3, nodes['$\overset{..}{q}$' + f'$_{i}$'])

    for node, layer in nodes.items():
        G.add_node(node, layer=layer)

    if mode=='NCAP':
        # Add edges between nodes
        edges_colors = ['green', 'orange', 'green', 'green']
        edge_labels = {
            ('o', '$o^d$'):'+1',
            ('o', '$o^v$'):'-1',
            ('$o^d$', '$b^d_1$'):'o',
            ('$o^v$', '$b^v_1$'):'o'
            }

        if include_speed_control:
          edges_colors += ['orange']
          edge_labels[('1-s', '$b^d_1$')] = 's, to all b'
        if include_turn_control:
          edges_colors += ['green', 'green']
          edge_labels[('r', '$b^d_1$')] = 't'
          edge_labels[('l', '$b^v_1$')] = 't'


        for i in range(1,N+1):
          if i < N:
            edges_colors += ['green', 'orange', 'green', 'green']

            edge_labels[((f'$q_{i}$', f'$q^d_{i}$'))] = '+1'
            edge_labels[((f'$q_{i}$', f'$q^v_{i}$'))] = '-1'
            edge_labels[((f'$q^d_{i}$', f'$b^d_{i+1}$'))] = 'p'
            edge_labels[((f'$q^v_{i}$', f'$b^v_{i+1}$'))] = 'p'

          edges_colors += ['green', 'orange', 'green', 'orange',
                          'orange', 'green']

          edge_labels[((f'$b^d_{i}$', f'$m^d_{i}$'))] = 'i'
          edge_labels[((f'$b^d_{i}$', f'$m^v_{i}$'))] = 'c'
          edge_labels[((f'$b^v_{i}$', f'$m^v_{i}$'))] = 'i'
          edge_labels[((f'$b^v_{i}$', f'$m^d_{i}$'))] = 'c'
          edge_labels[((f'$m^v_{i}$', '$\overset{..}{q}$' + f'$_{i}$'))] = '-1'
          edge_labels[((f'$m^d_{i}$', '$\overset{..}{q}$' + f'$_{i}$'))] = '+1'

        edges = edge_labels.keys()

    elif mode=='MLP':
      edges = []
      layers = [1, 1.5, 2, 2.5, 3]
      layers_nodes = [[], [], [], [], []]
      for key, value in custom_node_positions.items():
        ind = layers.index(value[0])
        layers_nodes[ind].append(key)
      for layer_ind in range(len(layers_nodes) - 1):
        for node1 in layers_nodes[layer_ind]:
          for node2 in layers_nodes[layer_ind+1]:
            edges.append((node1, node2))
      edges_colors = np.repeat('gray', len(edges))


    G.add_edges_from(edges)

    # Draw the graph using the custom node positions
    options = {"edge_color": edges_colors, "edgecolors": "tab:gray", "node_size": 500, 'node_color':'white'}
    nx.draw(G, pos=custom_node_positions, with_labels=True, arrowstyle="-", arrowsize=20, **options)
    if mode=='NCAP':
      nx.draw_networkx_edge_labels(G, pos=custom_node_positions, edge_labels=edge_labels)

# %%
draw_network('MLP', N=6)

# %%
draw_network('NCAP', N=6, include_speed_control=True, include_turn_control=True)

# %% [markdown]
# Notice that the NCAP architecture is highly sparse and interpretable as compared to the MLP. Moreover notice that the ncap architecture can be completely embedded within a fully connected MLP of 3 hidden layers and ReLU nonlinearities. This enables us to do a thorough investigation into how specific architectural elements influence both performance and the learning process. By leveraging this capability, we can systematically analyze the impact of the architectural preferences inherent to the model and make better design choices.

# %% [markdown]
# *It might be useful to also visualize the network's activity for NCAP. Given it only has 4 learnable parameters it becomes much easier to interpret the network.*

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_visualizing_the_sparse_network")

# %% [markdown]
# ---
# ## Conclusion

# %% [markdown]
# Based on the concepts we've discussed in this tutorial, you should now be equipped to advance with the project. Within this project, there are multiple pathways you can explore. For each pathway, you will delve deeply into one of the main sections outlined in this notebook, allowing for a thorough investigation of different factors that can influence performance:
#
# *   ***Exploring the effects of environment:*** Investigate how different environmental settings impact agent performance. This could involve altering parameters of the environment or the types of tasks and reward functions. Understanding these effects can help in making better architectural choices and learning algorithms that result in agents that are robust and adaptable
#
#
# *   ***Exploring the effects of learning algorithms:*** Standard RL algorithms often struggle with sparse and constrained networks, which can lead to suboptimal performance. Explore where these algorithms fail and analyze potential reasons for their limitations. Experiment with modifications or alternative algorithms that might overcome these challenges.
#
#
# * ***Exploring the effects of model architecture:*** Investigate how various architectural decisions within the NCAP model influence its performance. Visualize the model and its activity and explore potential improvements by tweaking architectural elements, assessing how these changes affect learning outcomes and operational efficiency.
